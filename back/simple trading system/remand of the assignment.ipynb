# %% [markdown]
# 1. 基于第五课的课件，添加一些条件；
# 2. 涨跌停限制；
# 3. 止损
# 4. 233， 貌似就这些，感觉还是很儿戏啊。。。

# %% [markdown]
# 1. 回测发现加入了止损后，总资产反而下降了；
# 1. 在surface上测试了第8课的代码，用compare对比第5课和第8课的代码区别, 使用第8课代码中的一些计算指标; 胜率怎么办, 2333
# 1. 将回测时间设定为2016-01-01~2018-06-30, 和前几次作业来个大对比; 看看不同策略在相同时间下的表现;
# 1. 加入仓位图;
# 1. 调整10%回测比率, 比如改成5%;
# 1. 使用固定比例浮动止损;
# 1. 使用波动率止损;
# 1. 使用均匀加仓;
# 1. 使用波动率分配头寸;
# 1. 使用止盈;
# 1. 使用波动率浮动止盈;

# %% [markdown]
# 1. 首先是跑通第五课的代码；
# 2. 求涨跌停价格并保存到不复权的表中；
# 3. 有了这些条件，然后再在回测框架中添加涨跌停限制和止损

# %% [markdown]
# 先看看目前的进度
#
# 查看有哪些database，自己想看的database下面有哪些collection；

# %% [markdown]
# ```mongodb
# show dbs
#
# use quant_01
#
# show collection
# ```

# %% [markdown]
# 需要看下，比如daily和daily_hfq有哪些字段，分别有多少条数据

# %% [markdown]
# daily有的字段是
#
# code date index ohlc volume
#
# daily_hfq
# 亦是一样的
#
# 也就是说没有做除权因子等操作，也没有记录pre_close
#
# 也没有补全信息, and so on
#
# 当然也没有做涨跌停的价格录入

# %% [markdown]
# 回测代码中也有不少需要加索引的地方

# %% [markdown]
# 先梳理出执行顺序
#
# 再确认各个文件里需要index的地方，不光是爬取数据的地方，回测的地方也需要index
#
# database.py / stock_util.py --> daily_crawler.py -->
#
# basic_crawler.py --> daily_fixing.py -->
#
# compute_high_low_limit.py -->
#
# finance_report.py --> pe_computing.py -->
#
# stock_pool_strategy.py --> backtest.py

# %% [markdown]
# ```
# 可以同时运行的有哪些数据呢
#
# daily只是ohlc基本数据
#
# basic_crawler是获取basic的数据
#
# daily_fixing是补充is_trading字段、停牌时的数据、复权因子 和 pre_close
#
# compute_high_low_limit是为了计算涨跌停价格，所以需要前面的都完成以后才能计算；
#
# finance_report是一个独立的过程，可以与其他的过程同时进行
#
# pe_computing需要daily中的close和report的eps，在daily数据和finance_report数据之后才能计算，但是不知道别的数据库在更新daily的时候，会不会影响效率
#
# 233，pe的计算果然够慢，如果可能，需要尽快进行哦
#
# ```

# %% [markdown]
# ```
# 【编程题】为了让回测更接近于实际情况，需要在第5课中回测流程中引入以下逻辑：
#
# 1、引入涨停和跌停的判断，跌停时无法卖出，涨停时无法买入；
#
# 2、引入止损的风险控制，如果单日亏损超过3%或者累积亏损超过10%则第二天开盘价卖出。
#
# 要求编写完整的可执行代码。自行选定回测周期，附回测结果图。
#
# ```

# %% [markdown]
# 获取股票基本信息，使用新的接口
# tushare pro 哦
# 可能会造成各种不适应

# %%
import QUANTAXIS as QA

# %%
df = QA.QA_fetch_get_stock_min('tdx', '300257', '2015-01-01', '2018-10-26')
# Out:
# QUANTAXIS>> Selecting the Best Server IP of TDX
# USING DEFAULT STOCK IP
# USING DEFAULT FUTURE IP
# QUANTAXIS>> === The BEST SERVER ===
#  stock_ip 60.191.117.167 future_ip 202.103.36.71

# %%
import tushare as ts

# %%
print(ts.__version__)
# Out:
# 1.2.12

# %%
token = 'd5deeb2574ff968fbf7cfc89a379a1a2597b2ab6dc56989053ec32a9'
ts.set_token(token)

# %%
pro = ts.pro_api()

# %%
df = pro.trade_cal(exchange_id='', start_date='20180901', end_date='20181001', fields='exchange_id,cal_date,is_open,pretrade_date', is_open='0')

# %%
trade_dates = QA.trade_date_sse

# %%
QA.QAUtil.*date*?

# %%
trade_range = QA.QA_util_get_trade_range('2015-01-01', '2017-12-31')

# %%
ts.get_stock_basics('2015-01-01')

# %%
for _date in trade_range:
    if ts.get_stock_basics(_date) is not None:
        print(_date)
        break
# Out:
# 2016-08-09

# %%
QA.QA_util_get_last_day('2016-08-09')
# Out:
# '2016-08-08'

# %% [markdown]
# 针对backtest进行debug，看到底是哪里

# %% [markdown]
# 重构涨跌停计算方式

# %%
df = ts.get_stock_basics()

# %%
df.head()
# Out:
#          name industry area     pe  outstanding  totals  totalAssets  \
# code
# 002939    N长城       证券   深圳  44.14         3.10   31.03   5252933.00
# 000068   华控赛格      元器件   深圳   0.00        10.07   10.07    322020.63
# 300083   劲胜智能      元器件   广东  80.28        11.89   14.32   1152387.88
# 002076  雪 莱 特     家用电器   广东   0.00         4.45    7.78    236576.80
# 600758   红阳能源     煤炭开采   辽宁  50.67         6.76   13.31   1634608.75
#
#         liquidAssets  fixedAssets   reserved    ...     bvps    pb  \
# code                                            ...
# 002939          0.00     16134.07  767217.75    ...     5.25  1.73
# 000068     121044.25     17267.07  119316.82    ...     0.62  4.17
# 300083     743815.13    166480.66  366826.81    ...     3.93  0.74
# 002076     141012.47     26288.91   35599.85    ...     1.63  2.06
# 600758     713384.81    688764.81  340929.41    ...     4.08  0.88
#
#         timeToMarket       undp  perundp    rev  profit    gpr    npr  \
# code
# 002939      20181026  242751.80     0.78   0.00    0.00   0.00  23.52
# 000068      19970611 -173199.06    -1.72  -6.87  -88.95  36.36 -34.92
# 300083      20100520   46661.46     0.33  -4.70  -91.40  18.19   0.86
# 002076      20061025   11410.11     0.15 -23.74 -281.75  22.54 -10.28
# 600758      19961029   48556.18     0.36  -7.73  -89.50  16.04   1.28
#
#          holders
# code
# 002939  555970.0
# 000068   31608.0
# 300083   44942.0
# 002076   51163.0
# 600758   67730.0
#
# [5 rows x 22 columns]

# %%
start = '2015-01-01'
end = '2017-12-31'

# %%
codes = ts.get_stock_basics().index.tolist()

# %%
codes[:10]
# Out:
# ['002939',
#  '000068',
#  '300083',
#  '002076',
#  '600758',
#  '002708',
#  '600173',
#  '601162',
#  '000622',
#  '002377']

# %%
code = codes[1000]

# %%
code
# Out:
# '600353'

# %%
from database import DB_CONN

# %%
sample = np.random.choice(codes, 10)

# %%
sample = np.random.choice(codes, 20).tolist()

# %%
sample
# Out:
# ['600781',
#  '002110',
#  '600183',
#  '002568',
#  '603214',
#  '603345',
#  '000506',
#  '300517',
#  '603326',
#  '002159',
#  '603555',
#  '600439',
#  '002464',
#  '002545',
#  '002310',
#  '002409',
#  '002637',
#  '002805',
#  '002843',
#  '002553']

# %% [markdown]
# 如果初始日就是

# %%
st_mark = ['st', 'ST', '*st', '*ST']

total = len(sample)
for i,code in enumerate(sample):
    try:
        timeToMarket = DB_CONN['basic'].find_one({'code':code}, 
            projection={'code':True, 'timeToMarket':True, '_id':False})['timeToMarket']
    except:
        continue

    daily_cursor = DB_CONN['daily'].find(
            {'code':code, 'date':{'$lte': end, '$gte': timeToMarket}, 'index':False},
            projection={'code':True, 'date':True, 'pre_close':True, '_id':False})

    for j,daily in enumerate(daily_cursor):
        date = daily['date']
        
        try:
            pre_close = daily['pre_close']
        except:
            if (j == 0) & (timeToMarket != date):
                pass
#                 print('code: %s, time: %s, 数据初始日没有pre_close' % (code, date))
            elif timeToMarket == date:
                issueprice = DB_CONN['basic'].find_one({'code':code},
                          projection={'issueprice':True, '_id':False})['issueprice']

                high_limit = np.round(np.round(issueprice * 1.2, 2) * 1.2, 2)
                low_limit = np.round(np.round(issueprice * 0.8, 2) * 0.8, 2)
            else:
                print('code: %s, time: %s, ipo_date: %s， 请速查原因' % (code, date, timeToMarket))
            continue
        
        
#         print('code: %s, date: %s' % (code, date))
        if date < '2016-08-09':
            _date = '2016-08-09'
        else:
            _date = date
        try:
            name = DB_CONN['basic'].find_one({'code':code, 'date':_date},
                          projection={'name':True, '_id':False})['name']
            last_name = name
        except:
            if i == 0:
                name = DB_CONN['basic'].find_one({'code':code},
                  projection={'name':True, '_id':False})['name']
                last_name = name
            else:
                name = last_name

#         if timeToMarket == date:
#             issueprice = DB_CONN['basic'].find_one({'code':code},
#                       projection={'issueprice':True, '_id':False})['issueprice']

#             high_limit = np.round(np.round(issueprice * 1.2, 2) * 1.2, 2)
#             low_limit = np.round(np.round(issueprice * 0.8, 2) * 0.8, 2)

        if (name[:2] in st_mark) or (name[:3] in st_mark) :
            high_limit = np.round(pre_close * 1.05, 2)
            low_limit = np.round(pre_close * 0.95, 2)

        else:
            high_limit = np.round(pre_close * 1.1, 2)
            low_limit = np.round(pre_close * 0.9, 2)
    print('stock: %s high low limit complish, 进度: (%s/%s)' % (code, i+1, total))
# Out:
# stock: 600781 high low limit complish, 进度: (1/20)
# stock: 002110 high low limit complish, 进度: (2/20)
# stock: 600183 high low limit complish, 进度: (3/20)
# stock: 002568 high low limit complish, 进度: (4/20)
# stock: 603345 high low limit complish, 进度: (6/20)
# stock: 000506 high low limit complish, 进度: (7/20)
# stock: 300517 high low limit complish, 进度: (8/20)
# stock: 603326 high low limit complish, 进度: (9/20)
# stock: 002159 high low limit complish, 进度: (10/20)
# stock: 603555 high low limit complish, 进度: (11/20)
# stock: 600439 high low limit complish, 进度: (12/20)
# stock: 002464 high low limit complish, 进度: (13/20)
# stock: 002545 high low limit complish, 进度: (14/20)
# stock: 002310 high low limit complish, 进度: (15/20)
# stock: 002409 high low limit complish, 进度: (16/20)
# stock: 002637 high low limit complish, 进度: (17/20)
# stock: 002805 high low limit complish, 进度: (18/20)
# stock: 002843 high low limit complish, 进度: (19/20)
# stock: 002553 high low limit complish, 进度: (20/20)

# %%
code = '000068'

timeToMarket = DB_CONN['basic'].find_one({'code':code}, 
    projection={'code':True, 'timeToMarket':True, '_id':False})['timeToMarket']

# %%
timeToMarket
# Out:
# '1997-06-11'

# %%
daily_cursor = DB_CONN['daily'].find(
            {'code':code, 'date':{'$lte': end, '$gte': timeToMarket}, 'index':False},
            projection={'code':True, 'date':True, 'pre_close':True, '_id':False})

# %%
result = [i for i in daily_cursor]

# %%
result
# Out:
# [{'code': '000068', 'date': '2015-01-05'},
#  {'code': '000068', 'date': '2015-01-06', 'pre_close': 8.47},
#  {'code': '000068', 'date': '2015-01-07', 'pre_close': 8.52},
#  {'code': '000068', 'date': '2015-01-08', 'pre_close': 8.61},
#  {'code': '000068', 'date': '2015-01-09', 'pre_close': 8.49},
#  {'code': '000068', 'date': '2015-01-12', 'pre_close': 8.5},
#  {'code': '000068', 'date': '2015-01-13', 'pre_close': 8.35},
#  {'code': '000068', 'date': '2015-01-14', 'pre_close': 8.38},
#  {'code': '000068', 'date': '2015-01-15', 'pre_close': 8.6},
#  {'code': '000068', 'date': '2015-01-16', 'pre_close': 8.26},
#  {'code': '000068', 'date': '2015-01-19', 'pre_close': 9.09},
#  {'code': '000068', 'date': '2015-01-20', 'pre_close': 9.18},
#  {'code': '000068', 'date': '2015-01-21', 'pre_close': 9.42},
#  {'code': '000068', 'date': '2015-01-22', 'pre_close': 9.3},
#  {'code': '000068', 'date': '2015-01-23', 'pre_close': 9.46},
#  {'code': '000068', 'date': '2015-01-26', 'pre_close': 9.52},
#  {'code': '000068', 'date': '2015-01-27', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-01-28', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-01-29', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-01-30', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-02', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-03', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-04', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-05', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-06', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-09', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-10', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-11', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-12', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-13', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-16', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-17', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-25', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-26', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-02-27', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-02', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-03', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-04', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-05', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-06', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-09', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-10', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-11', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-12', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-13', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-16', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-17', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-18', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-19', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-20', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-23', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-24', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-25', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-26', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-27', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-30', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-03-31', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-01', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-02', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-03', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-07', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-08', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-09', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-10', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-13', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-14', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-15', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-16', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-17', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-20', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-21', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-22', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-23', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-24', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-27', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-28', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-29', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-04-30', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-04', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-05', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-06', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-07', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-08', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-11', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-12', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-13', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-14', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-15', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-18', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-19', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-20', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-21', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-22', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-25', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-26', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-27', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-28', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-05-29', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-01', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-02', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-03', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-04', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-05', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-08', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-09', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-10', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-11', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-12', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-15', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-16', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-17', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-18', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-19', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-23', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-24', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-25', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-26', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-29', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-06-30', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-01', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-02', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-03', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-06', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-07', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-08', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-09', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-10', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-13', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-14', 'pre_close': 10.09},
#  {'code': '000068', 'date': '2015-07-15', 'pre_close': 10.59},
#  {'code': '000068', 'date': '2015-07-16', 'pre_close': 10.06},
#  {'code': '000068', 'date': '2015-07-17', 'pre_close': 9.56},
#  {'code': '000068', 'date': '2015-07-20', 'pre_close': 9.2},
#  {'code': '000068', 'date': '2015-07-21', 'pre_close': 9.49},
#  {'code': '000068', 'date': '2015-07-22', 'pre_close': 9.53},
#  {'code': '000068', 'date': '2015-07-23', 'pre_close': 9.42},
#  {'code': '000068', 'date': '2015-07-24', 'pre_close': 9.46},
#  {'code': '000068', 'date': '2015-07-27', 'pre_close': 9.93},
#  {'code': '000068', 'date': '2015-07-28', 'pre_close': 9.95},
#  {'code': '000068', 'date': '2015-07-29', 'pre_close': 10.11},
#  {'code': '000068', 'date': '2015-07-30', 'pre_close': 10.62},
#  {'code': '000068', 'date': '2015-07-31', 'pre_close': 11.15},
#  {'code': '000068', 'date': '2015-08-03', 'pre_close': 11.69},
#  {'code': '000068', 'date': '2015-08-04', 'pre_close': 11.11},
#  {'code': '000068', 'date': '2015-08-05', 'pre_close': 10.87},
#  {'code': '000068', 'date': '2015-08-06', 'pre_close': 11.41},
#  {'code': '000068', 'date': '2015-08-07', 'pre_close': 11.98},
#  {'code': '000068', 'date': '2015-08-10', 'pre_close': 12.22},
#  {'code': '000068', 'date': '2015-08-11', 'pre_close': 12.83},
#  {'code': '000068', 'date': '2015-08-12', 'pre_close': 12.75},
#  {'code': '000068', 'date': '2015-08-13', 'pre_close': 12.83},
#  {'code': '000068', 'date': '2015-08-14', 'pre_close': 13.47},
#  {'code': '000068', 'date': '2015-08-17', 'pre_close': 14.14},
#  {'code': '000068', 'date': '2015-08-18', 'pre_close': 14.85},
#  {'code': '000068', 'date': '2015-08-19', 'pre_close': 14.11},
#  {'code': '000068', 'date': '2015-08-20', 'pre_close': 14.38},
#  {'code': '000068', 'date': '2015-08-21', 'pre_close': 13.66},
#  {'code': '000068', 'date': '2015-08-24', 'pre_close': 12.98},
#  {'code': '000068', 'date': '2015-08-25', 'pre_close': 12.33},
#  {'code': '000068', 'date': '2015-08-26', 'pre_close': 11.71},
#  {'code': '000068', 'date': '2015-08-27', 'pre_close': 11.12},
#  {'code': '000068', 'date': '2015-08-28', 'pre_close': 10.56},
#  {'code': '000068', 'date': '2015-08-31', 'pre_close': 11.09},
#  {'code': '000068', 'date': '2015-09-01', 'pre_close': 10.54},
#  {'code': '000068', 'date': '2015-09-02', 'pre_close': 10.01},
#  {'code': '000068', 'date': '2015-09-07', 'pre_close': 9.51},
#  {'code': '000068', 'date': '2015-09-08', 'pre_close': 9.38},
#  {'code': '000068', 'date': '2015-09-09', 'pre_close': 9.74},
#  {'code': '000068', 'date': '2015-09-10', 'pre_close': 10.23},
#  {'code': '000068', 'date': '2015-09-11', 'pre_close': 10.15},
#  {'code': '000068', 'date': '2015-09-14', 'pre_close': 9.97},
#  {'code': '000068', 'date': '2015-09-15', 'pre_close': 9.47},
#  {'code': '000068', 'date': '2015-09-16', 'pre_close': 9.0},
#  {'code': '000068', 'date': '2015-09-17', 'pre_close': 9.16},
#  {'code': '000068', 'date': '2015-09-18', 'pre_close': 8.7},
#  {'code': '000068', 'date': '2015-09-21', 'pre_close': 8.27},
#  {'code': '000068', 'date': '2015-09-22', 'pre_close': 8.68},
#  {'code': '000068', 'date': '2015-09-23', 'pre_close': 8.84},
#  {'code': '000068', 'date': '2015-09-24', 'pre_close': 9.28},
#  {'code': '000068', 'date': '2015-09-25', 'pre_close': 9.74},
#  {'code': '000068', 'date': '2015-09-28', 'pre_close': 9.74},
#  {'code': '000068', 'date': '2015-09-29', 'pre_close': 10.23},
#  {'code': '000068', 'date': '2015-09-30', 'pre_close': 9.72},
#  {'code': '000068', 'date': '2015-10-08', 'pre_close': 9.72},
#  {'code': '000068', 'date': '2015-10-09', 'pre_close': 10.1},
#  {'code': '000068', 'date': '2015-10-12', 'pre_close': 9.99},
#  {'code': '000068', 'date': '2015-10-13', 'pre_close': 10.49},
#  {'code': '000068', 'date': '2015-10-14', 'pre_close': 10.6},
#  {'code': '000068', 'date': '2015-10-15', 'pre_close': 10.22},
#  {'code': '000068', 'date': '2015-10-16', 'pre_close': 10.53},
#  {'code': '000068', 'date': '2015-10-19', 'pre_close': 11.06},
#  {'code': '000068', 'date': '2015-10-20', 'pre_close': 11.61},
#  {'code': '000068', 'date': '2015-10-21', 'pre_close': 11.97},
#  {'code': '000068', 'date': '2015-10-22', 'pre_close': 11.37},
#  {'code': '000068', 'date': '2015-10-23', 'pre_close': 11.52},
#  {'code': '000068', 'date': '2015-10-26', 'pre_close': 11.7},
#  {'code': '000068', 'date': '2015-10-27', 'pre_close': 11.49},
#  {'code': '000068', 'date': '2015-10-28', 'pre_close': 12.06},
#  {'code': '000068', 'date': '2015-10-29', 'pre_close': 11.61},
#  {'code': '000068', 'date': '2015-10-30', 'pre_close': 11.63},
#  {'code': '000068', 'date': '2015-11-02', 'pre_close': 11.8},
#  {'code': '000068', 'date': '2015-11-03', 'pre_close': 11.55},
#  {'code': '000068', 'date': '2015-11-04', 'pre_close': 11.24},
#  {'code': '000068', 'date': '2015-11-05', 'pre_close': 11.79},
#  {'code': '000068', 'date': '2015-11-06', 'pre_close': 11.51},
#  {'code': '000068', 'date': '2015-11-09', 'pre_close': 11.93},
#  {'code': '000068', 'date': '2015-11-10', 'pre_close': 12.03},
#  {'code': '000068', 'date': '2015-11-11', 'pre_close': 12.49},
#  {'code': '000068', 'date': '2015-11-12', 'pre_close': 12.45},
#  {'code': '000068', 'date': '2015-11-13', 'pre_close': 12.54},
#  {'code': '000068', 'date': '2015-11-16', 'pre_close': 12.05},
#  {'code': '000068', 'date': '2015-11-17', 'pre_close': 12.12},
#  {'code': '000068', 'date': '2015-11-18', 'pre_close': 12.08},
#  {'code': '000068', 'date': '2015-11-19', 'pre_close': 12.0},
#  {'code': '000068', 'date': '2015-11-20', 'pre_close': 12.14},
#  {'code': '000068', 'date': '2015-11-23', 'pre_close': 12.22},
#  {'code': '000068', 'date': '2015-11-24', 'pre_close': 11.98},
#  {'code': '000068', 'date': '2015-11-25', 'pre_close': 11.7},
#  {'code': '000068', 'date': '2015-11-26', 'pre_close': 11.68},
#  {'code': '000068', 'date': '2015-11-27', 'pre_close': 11.38},
#  {'code': '000068', 'date': '2015-11-30', 'pre_close': 10.92},
#  {'code': '000068', 'date': '2015-12-01', 'pre_close': 10.86},
#  {'code': '000068', 'date': '2015-12-02', 'pre_close': 10.74},
#  {'code': '000068', 'date': '2015-12-03', 'pre_close': 10.67},
#  {'code': '000068', 'date': '2015-12-04', 'pre_close': 11.2},
#  {'code': '000068', 'date': '2015-12-07', 'pre_close': 11.75},
#  {'code': '000068', 'date': '2015-12-08', 'pre_close': 11.71},
#  {'code': '000068', 'date': '2015-12-09', 'pre_close': 11.48},
#  {'code': '000068', 'date': '2015-12-10', 'pre_close': 11.31},
#  {'code': '000068', 'date': '2015-12-11', 'pre_close': 11.88},
#  {'code': '000068', 'date': '2015-12-14', 'pre_close': 11.77},
#  {'code': '000068', 'date': '2015-12-15', 'pre_close': 11.94},
#  {'code': '000068', 'date': '2015-12-16', 'pre_close': 12.15},
#  {'code': '000068', 'date': '2015-12-17', 'pre_close': 12.0},
#  {'code': '000068', 'date': '2015-12-18', 'pre_close': 12.1},
#  {'code': '000068', 'date': '2015-12-21', 'pre_close': 11.98},
#  {'code': '000068', 'date': '2015-12-22', 'pre_close': 12.58},
#  {'code': '000068', 'date': '2015-12-23', 'pre_close': 13.21},
#  {'code': '000068', 'date': '2015-12-24', 'pre_close': 12.82},
#  {'code': '000068', 'date': '2015-12-25', 'pre_close': 13.06},
#  {'code': '000068', 'date': '2015-12-28', 'pre_close': 13.43},
#  {'code': '000068', 'date': '2015-12-29', 'pre_close': 12.76},
#  {'code': '000068', 'date': '2015-12-30', 'pre_close': 12.86},
#  {'code': '000068', 'date': '2015-12-31', 'pre_close': 12.52},
#  {'code': '000068', 'date': '2016-01-04', 'pre_close': 12.67},
#  {'code': '000068', 'date': '2016-01-05', 'pre_close': 12.04},
#  {'code': '000068', 'date': '2016-01-06', 'pre_close': 11.44},
#  {'code': '000068', 'date': '2016-01-07', 'pre_close': 11.39},
#  {'code': '000068', 'date': '2016-01-08', 'pre_close': 10.82},
#  {'code': '000068', 'date': '2016-01-11', 'pre_close': 10.29},
#  {'code': '000068', 'date': '2016-01-12', 'pre_close': 9.78},
#  {'code': '000068', 'date': '2016-01-13', 'pre_close': 9.29},
#  {'code': '000068', 'date': '2016-01-14', 'pre_close': 8.91},
#  {'code': '000068', 'date': '2016-01-15', 'pre_close': 9.01},
#  {'code': '000068', 'date': '2016-01-18', 'pre_close': 8.6},
#  {'code': '000068', 'date': '2016-01-19', 'pre_close': 8.53},
#  {'code': '000068', 'date': '2016-01-20', 'pre_close': 8.96},
#  {'code': '000068', 'date': '2016-01-21', 'pre_close': 9.0},
#  {'code': '000068', 'date': '2016-01-22', 'pre_close': 8.55},
#  {'code': '000068', 'date': '2016-01-25', 'pre_close': 8.58},
#  {'code': '000068', 'date': '2016-01-26', 'pre_close': 8.95},
#  {'code': '000068', 'date': '2016-01-27', 'pre_close': 8.51},
#  {'code': '000068', 'date': '2016-01-28', 'pre_close': 8.71},
#  {'code': '000068', 'date': '2016-01-29', 'pre_close': 8.4},
#  {'code': '000068', 'date': '2016-02-01', 'pre_close': 8.69},
#  {'code': '000068', 'date': '2016-02-02', 'pre_close': 8.88},
#  {'code': '000068', 'date': '2016-02-03', 'pre_close': 9.06},
#  {'code': '000068', 'date': '2016-02-04', 'pre_close': 9.22},
#  {'code': '000068', 'date': '2016-02-05', 'pre_close': 9.11},
#  {'code': '000068', 'date': '2016-02-15', 'pre_close': 9.35},
#  {'code': '000068', 'date': '2016-02-16', 'pre_close': 9.32},
#  {'code': '000068', 'date': '2016-02-17', 'pre_close': 9.72},
#  {'code': '000068', 'date': '2016-02-18', 'pre_close': 10.21},
#  {'code': '000068', 'date': '2016-02-19', 'pre_close': 10.1},
#  {'code': '000068', 'date': '2016-02-22', 'pre_close': 10.14},
#  {'code': '000068', 'date': '2016-02-23', 'pre_close': 10.3},
#  {'code': '000068', 'date': '2016-02-24', 'pre_close': 10.08},
#  {'code': '000068', 'date': '2016-02-25', 'pre_close': 10.07},
#  {'code': '000068', 'date': '2016-02-26', 'pre_close': 9.57},
#  {'code': '000068', 'date': '2016-02-29', 'pre_close': 9.13},
#  {'code': '000068', 'date': '2016-03-01', 'pre_close': 8.67},
#  {'code': '000068', 'date': '2016-03-02', 'pre_close': 8.79},
#  {'code': '000068', 'date': '2016-03-03', 'pre_close': 9.18},
#  {'code': '000068', 'date': '2016-03-04', 'pre_close': 9.6},
#  {'code': '000068', 'date': '2016-03-07', 'pre_close': 9.24},
#  {'code': '000068', 'date': '2016-03-08', 'pre_close': 9.45},
#  {'code': '000068', 'date': '2016-03-09', 'pre_close': 9.63},
#  {'code': '000068', 'date': '2016-03-10', 'pre_close': 9.37},
#  {'code': '000068', 'date': '2016-03-11', 'pre_close': 9.06},
#  {'code': '000068', 'date': '2016-03-14', 'pre_close': 9.0},
#  {'code': '000068', 'date': '2016-03-15', 'pre_close': 9.45},
#  {'code': '000068', 'date': '2016-03-16', 'pre_close': 9.35},
#  {'code': '000068', 'date': '2016-03-17', 'pre_close': 9.57},
#  {'code': '000068', 'date': '2016-03-18', 'pre_close': 9.66},
#  {'code': '000068', 'date': '2016-03-21', 'pre_close': 9.83},
#  {'code': '000068', 'date': '2016-03-22', 'pre_close': 10.0},
#  {'code': '000068', 'date': '2016-03-23', 'pre_close': 9.83},
#  {'code': '000068', 'date': '2016-03-24', 'pre_close': 9.89},
#  {'code': '000068', 'date': '2016-03-25', 'pre_close': 10.01},
#  {'code': '000068', 'date': '2016-03-28', 'pre_close': 10.42},
#  {'code': '000068', 'date': '2016-03-29', 'pre_close': 10.46},
#  {'code': '000068', 'date': '2016-03-30', 'pre_close': 10.13},
#  {'code': '000068', 'date': '2016-03-31', 'pre_close': 10.6},
#  {'code': '000068', 'date': '2016-04-01', 'pre_close': 10.34},
#  {'code': '000068', 'date': '2016-04-05', 'pre_close': 10.47},
#  {'code': '000068', 'date': '2016-04-06', 'pre_close': 10.48},
#  {'code': '000068', 'date': '2016-04-07', 'pre_close': 10.59},
#  {'code': '000068', 'date': '2016-04-08', 'pre_close': 10.3},
#  {'code': '000068', 'date': '2016-04-11', 'pre_close': 10.38},
#  {'code': '000068', 'date': '2016-04-12', 'pre_close': 10.38},
#  {'code': '000068', 'date': '2016-04-13', 'pre_close': 11.37},
#  {'code': '000068', 'date': '2016-04-14', 'pre_close': 11.15},
#  {'code': '000068', 'date': '2016-04-15', 'pre_close': 11.05},
#  {'code': '000068', 'date': '2016-04-18', 'pre_close': 11.08},
#  {'code': '000068', 'date': '2016-04-19', 'pre_close': 10.51},
#  {'code': '000068', 'date': '2016-04-20', 'pre_close': 10.36},
#  {'code': '000068', 'date': '2016-04-21', 'pre_close': 9.61},
#  {'code': '000068', 'date': '2016-04-22', 'pre_close': 9.24},
#  {'code': '000068', 'date': '2016-04-25', 'pre_close': 9.38},
#  {'code': '000068', 'date': '2016-04-26', 'pre_close': 9.3},
#  {'code': '000068', 'date': '2016-04-27', 'pre_close': 9.41},
#  {'code': '000068', 'date': '2016-04-28', 'pre_close': 9.44},
#  {'code': '000068', 'date': '2016-04-29', 'pre_close': 9.3},
#  {'code': '000068', 'date': '2016-05-03', 'pre_close': 9.28},
#  {'code': '000068', 'date': '2016-05-04', 'pre_close': 10.18},
#  {'code': '000068', 'date': '2016-05-05', 'pre_close': 9.71},
#  {'code': '000068', 'date': '2016-05-06', 'pre_close': 9.97},
#  {'code': '000068', 'date': '2016-05-09', 'pre_close': 9.59},
#  {'code': '000068', 'date': '2016-05-10', 'pre_close': 9.53},
#  {'code': '000068', 'date': '2016-05-11', 'pre_close': 9.72},
#  {'code': '000068', 'date': '2016-05-12', 'pre_close': 9.43},
#  {'code': '000068', 'date': '2016-05-13', 'pre_close': 9.71},
#  {'code': '000068', 'date': '2016-05-16', 'pre_close': 9.55},
#  {'code': '000068', 'date': '2016-05-17', 'pre_close': 9.58},
#  {'code': '000068', 'date': '2016-05-18', 'pre_close': 9.7},
#  {'code': '000068', 'date': '2016-05-19', 'pre_close': 9.37},
#  {'code': '000068', 'date': '2016-05-20', 'pre_close': 9.35},
#  {'code': '000068', 'date': '2016-05-23', 'pre_close': 9.7},
#  {'code': '000068', 'date': '2016-05-24', 'pre_close': 10.02},
#  {'code': '000068', 'date': '2016-05-25', 'pre_close': 9.95},
#  {'code': '000068', 'date': '2016-05-26', 'pre_close': 9.86},
#  {'code': '000068', 'date': '2016-05-27', 'pre_close': 9.74},
#  {'code': '000068', 'date': '2016-05-30', 'pre_close': 9.82},
#  {'code': '000068', 'date': '2016-05-31', 'pre_close': 9.61},
#  {'code': '000068', 'date': '2016-06-01', 'pre_close': 9.95},
#  {'code': '000068', 'date': '2016-06-02', 'pre_close': 10.01},
#  {'code': '000068', 'date': '2016-06-03', 'pre_close': 10.2},
#  {'code': '000068', 'date': '2016-06-06', 'pre_close': 10.12},
#  {'code': '000068', 'date': '2016-06-07', 'pre_close': 10.19},
#  {'code': '000068', 'date': '2016-06-08', 'pre_close': 10.17},
#  {'code': '000068', 'date': '2016-06-13', 'pre_close': 10.15},
#  {'code': '000068', 'date': '2016-06-14', 'pre_close': 9.56},
#  {'code': '000068', 'date': '2016-06-15', 'pre_close': 9.52},
#  {'code': '000068', 'date': '2016-06-16', 'pre_close': 9.72},
#  {'code': '000068', 'date': '2016-06-17', 'pre_close': 9.78},
#  {'code': '000068', 'date': '2016-06-20', 'pre_close': 9.69},
#  {'code': '000068', 'date': '2016-06-21', 'pre_close': 9.64},
#  {'code': '000068', 'date': '2016-06-22', 'pre_close': 9.51},
#  {'code': '000068', 'date': '2016-06-23', 'pre_close': 9.58},
#  {'code': '000068', 'date': '2016-06-24', 'pre_close': 9.58},
#  {'code': '000068', 'date': '2016-06-27', 'pre_close': 9.36},
#  {'code': '000068', 'date': '2016-06-28', 'pre_close': 9.7},
#  {'code': '000068', 'date': '2016-06-29', 'pre_close': 9.68},
#  {'code': '000068', 'date': '2016-06-30', 'pre_close': 9.64},
#  {'code': '000068', 'date': '2016-07-01', 'pre_close': 9.68},
#  {'code': '000068', 'date': '2016-07-04', 'pre_close': 9.56},
#  {'code': '000068', 'date': '2016-07-05', 'pre_close': 10.07},
#  {'code': '000068', 'date': '2016-07-06', 'pre_close': 10.15},
#  {'code': '000068', 'date': '2016-07-07', 'pre_close': 10.13},
#  {'code': '000068', 'date': '2016-07-08', 'pre_close': 10.26},
#  {'code': '000068', 'date': '2016-07-11', 'pre_close': 10.31},
#  {'code': '000068', 'date': '2016-07-12', 'pre_close': 10.08},
#  {'code': '000068', 'date': '2016-07-13', 'pre_close': 10.14},
#  {'code': '000068', 'date': '2016-07-14', 'pre_close': 10.2},
#  {'code': '000068', 'date': '2016-07-15', 'pre_close': 10.03},
#  {'code': '000068', 'date': '2016-07-18', 'pre_close': 9.89},
#  {'code': '000068', 'date': '2016-07-19', 'pre_close': 9.73},
#  {'code': '000068', 'date': '2016-07-20', 'pre_close': 10.29},
#  {'code': '000068', 'date': '2016-07-21', 'pre_close': 10.05},
#  {'code': '000068', 'date': '2016-07-22', 'pre_close': 9.99},
#  {'code': '000068', 'date': '2016-07-25', 'pre_close': 9.89},
#  {'code': '000068', 'date': '2016-07-26', 'pre_close': 9.78},
#  {'code': '000068', 'date': '2016-07-27', 'pre_close': 9.82},
#  {'code': '000068', 'date': '2016-07-28', 'pre_close': 9.61},
#  {'code': '000068', 'date': '2016-07-29', 'pre_close': 9.6},
#  {'code': '000068', 'date': '2016-08-01', 'pre_close': 9.4},
#  {'code': '000068', 'date': '2016-08-02', 'pre_close': 9.24},
#  {'code': '000068', 'date': '2016-08-03', 'pre_close': 9.21},
#  {'code': '000068', 'date': '2016-08-04', 'pre_close': 9.23},
#  {'code': '000068', 'date': '2016-08-05', 'pre_close': 9.35},
#  {'code': '000068', 'date': '2016-08-08', 'pre_close': 9.1},
#  {'code': '000068', 'date': '2016-08-09', 'pre_close': 9.36},
#  {'code': '000068', 'date': '2016-08-10', 'pre_close': 9.4},
#  {'code': '000068', 'date': '2016-08-11', 'pre_close': 9.41},
#  {'code': '000068', 'date': '2016-08-12', 'pre_close': 9.33},
#  {'code': '000068', 'date': '2016-08-15', 'pre_close': 9.5},
#  {'code': '000068', 'date': '2016-08-16', 'pre_close': 9.58},
#  {'code': '000068', 'date': '2016-08-17', 'pre_close': 9.61},
#  {'code': '000068', 'date': '2016-08-18', 'pre_close': 9.5},
#  {'code': '000068', 'date': '2016-08-19', 'pre_close': 9.48},
#  {'code': '000068', 'date': '2016-08-22', 'pre_close': 9.45},
#  {'code': '000068', 'date': '2016-08-23', 'pre_close': 9.27},
#  {'code': '000068', 'date': '2016-08-24', 'pre_close': 9.28},
#  {'code': '000068', 'date': '2016-08-25', 'pre_close': 9.38},
#  {'code': '000068', 'date': '2016-08-26', 'pre_close': 9.22},
#  {'code': '000068', 'date': '2016-08-29', 'pre_close': 9.4},
#  {'code': '000068', 'date': '2016-08-30', 'pre_close': 10.34},
#  {'code': '000068', 'date': '2016-08-31', 'pre_close': 10.04},
#  {'code': '000068', 'date': '2016-09-01', 'pre_close': 9.99},
#  {'code': '000068', 'date': '2016-09-02', 'pre_close': 9.79},
#  {'code': '000068', 'date': '2016-09-05', 'pre_close': 9.8},
#  {'code': '000068', 'date': '2016-09-06', 'pre_close': 9.96},
#  {'code': '000068', 'date': '2016-09-07', 'pre_close': 10.38},
#  {'code': '000068', 'date': '2016-09-08', 'pre_close': 10.72},
#  {'code': '000068', 'date': '2016-09-09', 'pre_close': 10.83},
#  {'code': '000068', 'date': '2016-09-12', 'pre_close': 10.69},
#  {'code': '000068', 'date': '2016-09-13', 'pre_close': 10.58},
#  {'code': '000068', 'date': '2016-09-14', 'pre_close': 10.8},
#  {'code': '000068', 'date': '2016-09-19', 'pre_close': 10.2},
#  {'code': '000068', 'date': '2016-09-20', 'pre_close': 10.27},
#  {'code': '000068', 'date': '2016-09-21', 'pre_close': 10.18},
#  {'code': '000068', 'date': '2016-09-22', 'pre_close': 10.15},
#  {'code': '000068', 'date': '2016-09-23', 'pre_close': 10.19},
#  {'code': '000068', 'date': '2016-09-26', 'pre_close': 10.19},
#  {'code': '000068', 'date': '2016-09-27', 'pre_close': 9.6},
#  {'code': '000068', 'date': '2016-09-28', 'pre_close': 9.55},
#  {'code': '000068', 'date': '2016-09-29', 'pre_close': 9.55},
#  {'code': '000068', 'date': '2016-09-30', 'pre_close': 9.65},
#  {'code': '000068', 'date': '2016-10-10', 'pre_close': 9.7},
#  {'code': '000068', 'date': '2016-10-11', 'pre_close': 9.81},
#  {'code': '000068', 'date': '2016-10-12', 'pre_close': 10.03},
#  {'code': '000068', 'date': '2016-10-13', 'pre_close': 9.88},
#  {'code': '000068', 'date': '2016-10-14', 'pre_close': 9.87},
#  {'code': '000068', 'date': '2016-10-17', 'pre_close': 10.08},
#  {'code': '000068', 'date': '2016-10-18', 'pre_close': 9.8},
#  {'code': '000068', 'date': '2016-10-19', 'pre_close': 9.85},
#  {'code': '000068', 'date': '2016-10-20', 'pre_close': 9.75},
#  {'code': '000068', 'date': '2016-10-21', 'pre_close': 9.79},
#  {'code': '000068', 'date': '2016-10-24', 'pre_close': 9.69},
#  {'code': '000068', 'date': '2016-10-25', 'pre_close': 9.74},
#  {'code': '000068', 'date': '2016-10-26', 'pre_close': 9.59},
#  {'code': '000068', 'date': '2016-10-27', 'pre_close': 9.59},
#  {'code': '000068', 'date': '2016-10-28', 'pre_close': 9.58},
#  {'code': '000068', 'date': '2016-10-31', 'pre_close': 9.52},
#  {'code': '000068', 'date': '2016-11-01', 'pre_close': 9.4},
#  {'code': '000068', 'date': '2016-11-02', 'pre_close': 9.44},
#  {'code': '000068', 'date': '2016-11-03', 'pre_close': 9.35},
#  {'code': '000068', 'date': '2016-11-04', 'pre_close': 9.3},
#  {'code': '000068', 'date': '2016-11-07', 'pre_close': 9.38},
#  {'code': '000068', 'date': '2016-11-08', 'pre_close': 9.3},
#  {'code': '000068', 'date': '2016-11-09', 'pre_close': 9.38},
#  {'code': '000068', 'date': '2016-11-10', 'pre_close': 9.23},
#  {'code': '000068', 'date': '2016-11-11', 'pre_close': 9.44},
#  {'code': '000068', 'date': '2016-11-14', 'pre_close': 9.39},
#  {'code': '000068', 'date': '2016-11-15', 'pre_close': 9.35},
#  {'code': '000068', 'date': '2016-11-16', 'pre_close': 9.56},
#  {'code': '000068', 'date': '2016-11-17', 'pre_close': 9.49},
#  {'code': '000068', 'date': '2016-11-18', 'pre_close': 9.37},
#  {'code': '000068', 'date': '2016-11-21', 'pre_close': 9.38},
#  {'code': '000068', 'date': '2016-11-22', 'pre_close': 9.32},
#  {'code': '000068', 'date': '2016-11-23', 'pre_close': 9.38},
#  {'code': '000068', 'date': '2016-11-24', 'pre_close': 9.32},
#  {'code': '000068', 'date': '2016-11-25', 'pre_close': 9.23},
#  {'code': '000068', 'date': '2016-11-28', 'pre_close': 9.18},
#  {'code': '000068', 'date': '2016-11-29', 'pre_close': 9.19},
#  {'code': '000068', 'date': '2016-11-30', 'pre_close': 9.13},
#  {'code': '000068', 'date': '2016-12-01', 'pre_close': 9.14},
#  {'code': '000068', 'date': '2016-12-02', 'pre_close': 9.11},
#  {'code': '000068', 'date': '2016-12-05', 'pre_close': 9.02},
#  {'code': '000068', 'date': '2016-12-06', 'pre_close': 8.88},
#  {'code': '000068', 'date': '2016-12-07', 'pre_close': 8.95},
#  {'code': '000068', 'date': '2016-12-08', 'pre_close': 9.05},
#  {'code': '000068', 'date': '2016-12-09', 'pre_close': 8.93},
#  {'code': '000068', 'date': '2016-12-12', 'pre_close': 8.88},
#  {'code': '000068', 'date': '2016-12-13', 'pre_close': 8.39},
#  {'code': '000068', 'date': '2016-12-14', 'pre_close': 8.39},
#  {'code': '000068', 'date': '2016-12-15', 'pre_close': 8.22},
#  {'code': '000068', 'date': '2016-12-16', 'pre_close': 8.25},
#  {'code': '000068', 'date': '2016-12-19', 'pre_close': 8.34},
#  {'code': '000068', 'date': '2016-12-20', 'pre_close': 8.32},
#  {'code': '000068', 'date': '2016-12-21', 'pre_close': 8.31},
#  {'code': '000068', 'date': '2016-12-22', 'pre_close': 8.33},
#  {'code': '000068', 'date': '2016-12-23', 'pre_close': 8.46},
#  {'code': '000068', 'date': '2016-12-26', 'pre_close': 8.29},
#  {'code': '000068', 'date': '2016-12-27', 'pre_close': 8.29},
#  {'code': '000068', 'date': '2016-12-28', 'pre_close': 8.36},
#  {'code': '000068', 'date': '2016-12-29', 'pre_close': 8.9},
#  {'code': '000068', 'date': '2016-12-30', 'pre_close': 8.54},
#  {'code': '000068', 'date': '2017-01-03', 'pre_close': 8.32},
#  {'code': '000068', 'date': '2017-01-04', 'pre_close': 8.41},
#  {'code': '000068', 'date': '2017-01-05', 'pre_close': 8.6},
#  {'code': '000068', 'date': '2017-01-06', 'pre_close': 8.54},
#  {'code': '000068', 'date': '2017-01-09', 'pre_close': 8.56},
#  {'code': '000068', 'date': '2017-01-10', 'pre_close': 8.56},
#  {'code': '000068', 'date': '2017-01-11', 'pre_close': 8.47},
#  {'code': '000068', 'date': '2017-01-12', 'pre_close': 8.4},
#  {'code': '000068', 'date': '2017-01-13', 'pre_close': 8.31},
#  {'code': '000068', 'date': '2017-01-16', 'pre_close': 8.16},
#  {'code': '000068', 'date': '2017-01-17', 'pre_close': 7.85},
#  {'code': '000068', 'date': '2017-01-18', 'pre_close': 7.85},
#  {'code': '000068', 'date': '2017-01-19', 'pre_close': 7.81},
#  {'code': '000068', 'date': '2017-01-20', 'pre_close': 7.65},
#  {'code': '000068', 'date': '2017-01-23', 'pre_close': 7.68},
#  {'code': '000068', 'date': '2017-01-24', 'pre_close': 7.8},
#  {'code': '000068', 'date': '2017-01-25', 'pre_close': 8.01},
#  {'code': '000068', 'date': '2017-01-26', 'pre_close': 7.98},
#  {'code': '000068', 'date': '2017-02-03', 'pre_close': 8.0},
#  {'code': '000068', 'date': '2017-02-06', 'pre_close': 7.97},
#  {'code': '000068', 'date': '2017-02-07', 'pre_close': 8.02},
#  {'code': '000068', 'date': '2017-02-08', 'pre_close': 7.97},
#  {'code': '000068', 'date': '2017-02-09', 'pre_close': 7.98},
#  {'code': '000068', 'date': '2017-02-10', 'pre_close': 8.07},
#  {'code': '000068', 'date': '2017-02-13', 'pre_close': 8.06},
#  {'code': '000068', 'date': '2017-02-14', 'pre_close': 8.06},
#  {'code': '000068', 'date': '2017-02-15', 'pre_close': 8.03},
#  {'code': '000068', 'date': '2017-02-16', 'pre_close': 7.85},
#  {'code': '000068', 'date': '2017-02-17', 'pre_close': 7.86},
#  {'code': '000068', 'date': '2017-02-20', 'pre_close': 7.74},
#  {'code': '000068', 'date': '2017-02-21', 'pre_close': 7.9},
#  {'code': '000068', 'date': '2017-02-22', 'pre_close': 7.9},
#  {'code': '000068', 'date': '2017-02-23', 'pre_close': 7.95},
#  {'code': '000068', 'date': '2017-02-24', 'pre_close': 8.13},
#  {'code': '000068', 'date': '2017-02-27', 'pre_close': 8.13},
#  {'code': '000068', 'date': '2017-02-28', 'pre_close': 8.09},
#  {'code': '000068', 'date': '2017-03-01', 'pre_close': 8.09},
#  {'code': '000068', 'date': '2017-03-02', 'pre_close': 8.13},
#  {'code': '000068', 'date': '2017-03-03', 'pre_close': 7.99},
#  {'code': '000068', 'date': '2017-03-06', 'pre_close': 7.97},
#  {'code': '000068', 'date': '2017-03-07', 'pre_close': 8.17},
#  {'code': '000068', 'date': '2017-03-08', 'pre_close': 8.17},
#  {'code': '000068', 'date': '2017-03-09', 'pre_close': 8.17},
#  {'code': '000068', 'date': '2017-03-10', 'pre_close': 8.24},
#  {'code': '000068', 'date': '2017-03-13', 'pre_close': 8.1},
#  {'code': '000068', 'date': '2017-03-14', 'pre_close': 8.13},
#  {'code': '000068', 'date': '2017-03-15', 'pre_close': 8.06},
#  {'code': '000068', 'date': '2017-03-16', 'pre_close': 8.08},
#  {'code': '000068', 'date': '2017-03-17', 'pre_close': 8.12},
#  {'code': '000068', 'date': '2017-03-20', 'pre_close': 8.02},
#  {'code': '000068', 'date': '2017-03-21', 'pre_close': 8.03},
#  {'code': '000068', 'date': '2017-03-22', 'pre_close': 8.38},
#  {'code': '000068', 'date': '2017-03-23', 'pre_close': 8.18},
#  {'code': '000068', 'date': '2017-03-24', 'pre_close': 8.07},
#  {'code': '000068', 'date': '2017-03-27', 'pre_close': 8.06},
#  {'code': '000068', 'date': '2017-03-28', 'pre_close': 7.91},
#  {'code': '000068', 'date': '2017-03-29', 'pre_close': 7.82},
#  {'code': '000068', 'date': '2017-03-30', 'pre_close': 7.8},
#  {'code': '000068', 'date': '2017-03-31', 'pre_close': 7.5},
#  {'code': '000068', 'date': '2017-04-05', 'pre_close': 7.56},
#  {'code': '000068', 'date': '2017-04-06', 'pre_close': 7.81},
#  {'code': '000068', 'date': '2017-04-07', 'pre_close': 7.74},
#  {'code': '000068', 'date': '2017-04-10', 'pre_close': 8.15},
#  {'code': '000068', 'date': '2017-04-11', 'pre_close': 8.37},
#  {'code': '000068', 'date': '2017-04-12', 'pre_close': 8.61},
#  {'code': '000068', 'date': '2017-04-13', 'pre_close': 8.6},
#  {'code': '000068', 'date': '2017-04-14', 'pre_close': 8.9},
#  {'code': '000068', 'date': '2017-04-17', 'pre_close': 8.55},
#  {'code': '000068', 'date': '2017-04-18', 'pre_close': 8.28},
#  {'code': '000068', 'date': '2017-04-19', 'pre_close': 8.16},
#  {'code': '000068', 'date': '2017-04-20', 'pre_close': 8.07},
#  {'code': '000068', 'date': '2017-04-21', 'pre_close': 8.13},
#  {'code': '000068', 'date': '2017-04-24', 'pre_close': 7.95},
#  {'code': '000068', 'date': '2017-04-25', 'pre_close': 7.66},
#  {'code': '000068', 'date': '2017-04-26', 'pre_close': 7.6},
#  {'code': '000068', 'date': '2017-04-27', 'pre_close': 7.7},
#  {'code': '000068', 'date': '2017-04-28', 'pre_close': 7.99},
#  {'code': '000068', 'date': '2017-05-02', 'pre_close': 8.09},
#  {'code': '000068', 'date': '2017-05-03', 'pre_close': 8.18},
#  {'code': '000068', 'date': '2017-05-04', 'pre_close': 8.03},
#  {'code': '000068', 'date': '2017-05-05', 'pre_close': 8.39},
#  {'code': '000068', 'date': '2017-05-08', 'pre_close': 8.11},
#  {'code': '000068', 'date': '2017-05-09', 'pre_close': 7.8},
#  {'code': '000068', 'date': '2017-05-10', 'pre_close': 7.8},
#  {'code': '000068', 'date': '2017-05-11', 'pre_close': 7.74},
#  {'code': '000068', 'date': '2017-05-12', 'pre_close': 7.23},
#  {'code': '000068', 'date': '2017-05-15', 'pre_close': 7.15},
#  {'code': '000068', 'date': '2017-05-16', 'pre_close': 7.18},
#  {'code': '000068', 'date': '2017-05-17', 'pre_close': 7.3},
#  {'code': '000068', 'date': '2017-05-18', 'pre_close': 7.7},
#  {'code': '000068', 'date': '2017-05-19', 'pre_close': 7.55},
#  {'code': '000068', 'date': '2017-05-22', 'pre_close': 7.47},
#  {'code': '000068', 'date': '2017-05-23', 'pre_close': 7.3},
#  {'code': '000068', 'date': '2017-05-24', 'pre_close': 7.28},
#  {'code': '000068', 'date': '2017-05-25', 'pre_close': 7.35},
#  {'code': '000068', 'date': '2017-05-26', 'pre_close': 7.31},
#  {'code': '000068', 'date': '2017-05-31', 'pre_close': 7.26},
#  {'code': '000068', 'date': '2017-06-01', 'pre_close': 7.14},
#  {'code': '000068', 'date': '2017-06-02', 'pre_close': 6.6},
#  {'code': '000068', 'date': '2017-06-05', 'pre_close': 6.87},
#  {'code': '000068', 'date': '2017-06-06', 'pre_close': 6.98},
#  {'code': '000068', 'date': '2017-06-07', 'pre_close': 6.75},
#  {'code': '000068', 'date': '2017-06-08', 'pre_close': 7.17},
#  {'code': '000068', 'date': '2017-06-09', 'pre_close': 7.18},
#  {'code': '000068', 'date': '2017-06-12', 'pre_close': 7.09},
#  {'code': '000068', 'date': '2017-06-13', 'pre_close': 6.9},
#  {'code': '000068', 'date': '2017-06-14', 'pre_close': 6.91},
#  {'code': '000068', 'date': '2017-06-15', 'pre_close': 6.84},
#  {'code': '000068', 'date': '2017-06-16', 'pre_close': 6.88},
#  {'code': '000068', 'date': '2017-06-19', 'pre_close': 6.92},
#  {'code': '000068', 'date': '2017-06-20', 'pre_close': 6.86},
#  {'code': '000068', 'date': '2017-06-21', 'pre_close': 6.89},
#  {'code': '000068', 'date': '2017-06-22', 'pre_close': 6.95},
#  {'code': '000068', 'date': '2017-06-23', 'pre_close': 6.84},
#  {'code': '000068', 'date': '2017-06-26', 'pre_close': 6.74},
#  {'code': '000068', 'date': '2017-06-27', 'pre_close': 6.86},
#  {'code': '000068', 'date': '2017-06-28', 'pre_close': 7.08},
#  {'code': '000068', 'date': '2017-06-29', 'pre_close': 6.92},
#  {'code': '000068', 'date': '2017-06-30', 'pre_close': 7.0},
#  {'code': '000068', 'date': '2017-07-03', 'pre_close': 7.02},
#  {'code': '000068', 'date': '2017-07-04', 'pre_close': 7.0},
#  {'code': '000068', 'date': '2017-07-05', 'pre_close': 6.86},
#  {'code': '000068', 'date': '2017-07-06', 'pre_close': 6.91},
#  {'code': '000068', 'date': '2017-07-07', 'pre_close': 6.84},
#  {'code': '000068', 'date': '2017-07-10', 'pre_close': 6.83},
#  {'code': '000068', 'date': '2017-07-11', 'pre_close': 6.81},
#  {'code': '000068', 'date': '2017-07-12', 'pre_close': 6.75},
#  {'code': '000068', 'date': '2017-07-13', 'pre_close': 6.68},
#  {'code': '000068', 'date': '2017-07-14', 'pre_close': 6.7},
#  {'code': '000068', 'date': '2017-07-17', 'pre_close': 6.6},
#  {'code': '000068', 'date': '2017-07-18', 'pre_close': 6.34},
#  {'code': '000068', 'date': '2017-07-19', 'pre_close': 6.24},
#  {'code': '000068', 'date': '2017-07-20', 'pre_close': 6.6},
#  {'code': '000068', 'date': '2017-07-21', 'pre_close': 6.44},
#  {'code': '000068', 'date': '2017-07-24', 'pre_close': 6.31},
#  {'code': '000068', 'date': '2017-07-25', 'pre_close': 6.37},
#  {'code': '000068', 'date': '2017-07-26', 'pre_close': 6.29},
#  {'code': '000068', 'date': '2017-07-27', 'pre_close': 6.27},
#  {'code': '000068', 'date': '2017-07-28', 'pre_close': 6.31},
#  {'code': '000068', 'date': '2017-07-31', 'pre_close': 6.33},
#  {'code': '000068', 'date': '2017-08-01', 'pre_close': 6.32},
#  {'code': '000068', 'date': '2017-08-02', 'pre_close': 6.37},
#  {'code': '000068', 'date': '2017-08-03', 'pre_close': 6.38},
#  {'code': '000068', 'date': '2017-08-04', 'pre_close': 6.82},
#  {'code': '000068', 'date': '2017-08-07', 'pre_close': 6.8},
#  {'code': '000068', 'date': '2017-08-08', 'pre_close': 7.12},
#  {'code': '000068', 'date': '2017-08-09', 'pre_close': 6.9},
#  {'code': '000068', 'date': '2017-08-10', 'pre_close': 6.76},
#  {'code': '000068', 'date': '2017-08-11', 'pre_close': 6.66},
#  {'code': '000068', 'date': '2017-08-14', 'pre_close': 6.68},
#  {'code': '000068', 'date': '2017-08-15', 'pre_close': 6.86},
#  {'code': '000068', 'date': '2017-08-16', 'pre_close': 6.92},
#  {'code': '000068', 'date': '2017-08-17', 'pre_close': 6.85},
#  {'code': '000068', 'date': '2017-08-18', 'pre_close': 7.03},
#  {'code': '000068', 'date': '2017-08-21', 'pre_close': 7.14},
#  {'code': '000068', 'date': '2017-08-22', 'pre_close': 7.13},
#  {'code': '000068', 'date': '2017-08-23', 'pre_close': 7.08},
#  {'code': '000068', 'date': '2017-08-24', 'pre_close': 7.02},
#  {'code': '000068', 'date': '2017-08-25', 'pre_close': 6.88},
#  {'code': '000068', 'date': '2017-08-28', 'pre_close': 6.91},
#  {'code': '000068', 'date': '2017-08-29', 'pre_close': 6.9},
#  {'code': '000068', 'date': '2017-08-30', 'pre_close': 7.0},
#  {'code': '000068', 'date': '2017-08-31', 'pre_close': 6.87},
#  {'code': '000068', 'date': '2017-09-01', 'pre_close': 6.87},
#  {'code': '000068', 'date': '2017-09-04', 'pre_close': 6.83},
#  {'code': '000068', 'date': '2017-09-05', 'pre_close': 6.83},
#  {'code': '000068', 'date': '2017-09-06', 'pre_close': 6.83},
#  {'code': '000068', 'date': '2017-09-07', 'pre_close': 6.74},
#  {'code': '000068', 'date': '2017-09-08', 'pre_close': 6.73},
#  {'code': '000068', 'date': '2017-09-11', 'pre_close': 6.69},
#  {'code': '000068', 'date': '2017-09-12', 'pre_close': 6.63},
#  {'code': '000068', 'date': '2017-09-13', 'pre_close': 6.61},
#  {'code': '000068', 'date': '2017-09-14', 'pre_close': 7.27},
#  {'code': '000068', 'date': '2017-09-15', 'pre_close': 7.04},
#  {'code': '000068', 'date': '2017-09-18', 'pre_close': 7.11},
#  {'code': '000068', 'date': '2017-09-19', 'pre_close': 7.02},
#  {'code': '000068', 'date': '2017-09-20', 'pre_close': 7.21},
#  {'code': '000068', 'date': '2017-09-21', 'pre_close': 7.15},
#  {'code': '000068', 'date': '2017-09-22', 'pre_close': 7.06},
#  {'code': '000068', 'date': '2017-09-25', 'pre_close': 7.12},
#  {'code': '000068', 'date': '2017-09-26', 'pre_close': 6.88},
#  {'code': '000068', 'date': '2017-09-27', 'pre_close': 6.84},
#  {'code': '000068', 'date': '2017-09-28', 'pre_close': 6.82},
#  {'code': '000068', 'date': '2017-09-29', 'pre_close': 6.68},
#  {'code': '000068', 'date': '2017-10-09', 'pre_close': 7.09},
#  {'code': '000068', 'date': '2017-10-10', 'pre_close': 7.01},
#  {'code': '000068', 'date': '2017-10-11', 'pre_close': 7.04},
#  {'code': '000068', 'date': '2017-10-12', 'pre_close': 6.9},
#  {'code': '000068', 'date': '2017-10-13', 'pre_close': 6.86},
#  {'code': '000068', 'date': '2017-10-16', 'pre_close': 7.0},
#  {'code': '000068', 'date': '2017-10-17', 'pre_close': 6.8},
#  {'code': '000068', 'date': '2017-10-18', 'pre_close': 6.82},
#  {'code': '000068', 'date': '2017-10-19', 'pre_close': 6.63},
#  {'code': '000068', 'date': '2017-10-20', 'pre_close': 6.59},
#  {'code': '000068', 'date': '2017-10-23', 'pre_close': 6.69},
#  {'code': '000068', 'date': '2017-10-24', 'pre_close': 6.74},
#  {'code': '000068', 'date': '2017-10-25', 'pre_close': 6.65},
#  {'code': '000068', 'date': '2017-10-26', 'pre_close': 6.67},
#  {'code': '000068', 'date': '2017-10-27', 'pre_close': 6.64},
#  {'code': '000068', 'date': '2017-10-30', 'pre_close': 6.62},
#  {'code': '000068', 'date': '2017-10-31', 'pre_close': 6.31},
#  {'code': '000068', 'date': '2017-11-01', 'pre_close': 6.38},
#  {'code': '000068', 'date': '2017-11-02', 'pre_close': 6.34},
#  {'code': '000068', 'date': '2017-11-03', 'pre_close': 6.26},
#  {'code': '000068', 'date': '2017-11-06', 'pre_close': 6.43},
#  {'code': '000068', 'date': '2017-11-07', 'pre_close': 6.23},
#  {'code': '000068', 'date': '2017-11-08', 'pre_close': 6.23},
#  {'code': '000068', 'date': '2017-11-09', 'pre_close': 6.24},
#  {'code': '000068', 'date': '2017-11-10', 'pre_close': 6.31},
#  {'code': '000068', 'date': '2017-11-13', 'pre_close': 6.25},
#  {'code': '000068', 'date': '2017-11-14', 'pre_close': 6.29},
#  {'code': '000068', 'date': '2017-11-15', 'pre_close': 6.36},
#  {'code': '000068', 'date': '2017-11-16', 'pre_close': 6.34},
#  {'code': '000068', 'date': '2017-11-17', 'pre_close': 6.21},
#  {'code': '000068', 'date': '2017-11-20', 'pre_close': 5.95},
#  {'code': '000068', 'date': '2017-11-21', 'pre_close': 5.78},
#  {'code': '000068', 'date': '2017-11-22', 'pre_close': 5.69},
#  {'code': '000068', 'date': '2017-11-23', 'pre_close': 5.75},
#  {'code': '000068', 'date': '2017-11-24', 'pre_close': 5.61},
#  {'code': '000068', 'date': '2017-11-27', 'pre_close': 5.69},
#  {'code': '000068', 'date': '2017-11-28', 'pre_close': 5.58},
#  {'code': '000068', 'date': '2017-11-29', 'pre_close': 5.64},
#  {'code': '000068', 'date': '2017-11-30', 'pre_close': 5.59},
#  {'code': '000068', 'date': '2017-12-01', 'pre_close': 5.66},
#  {'code': '000068', 'date': '2017-12-04', 'pre_close': 5.75},
#  {'code': '000068', 'date': '2017-12-05', 'pre_close': 5.67},
#  {'code': '000068', 'date': '2017-12-06', 'pre_close': 5.41},
#  {'code': '000068', 'date': '2017-12-07', 'pre_close': 5.32},
#  {'code': '000068', 'date': '2017-12-08', 'pre_close': 5.3},
#  {'code': '000068', 'date': '2017-12-11', 'pre_close': 5.33},
#  {'code': '000068', 'date': '2017-12-12', 'pre_close': 5.35},
#  {'code': '000068', 'date': '2017-12-13', 'pre_close': 5.29},
#  {'code': '000068', 'date': '2017-12-14', 'pre_close': 5.33},
#  {'code': '000068', 'date': '2017-12-15', 'pre_close': 5.25},
#  {'code': '000068', 'date': '2017-12-18', 'pre_close': 5.25},
#  {'code': '000068', 'date': '2017-12-19', 'pre_close': 5.09},
#  {'code': '000068', 'date': '2017-12-20', 'pre_close': 5.14},
#  {'code': '000068', 'date': '2017-12-21', 'pre_close': 5.07},
#  {'code': '000068', 'date': '2017-12-22', 'pre_close': 5.13},
#  {'code': '000068', 'date': '2017-12-25', 'pre_close': 5.08},
#  {'code': '000068', 'date': '2017-12-26', 'pre_close': 5.0},
#  {'code': '000068', 'date': '2017-12-27', 'pre_close': 4.99},
#  {'code': '000068', 'date': '2017-12-28', 'pre_close': 5.02},
#  {'code': '000068', 'date': '2017-12-29', 'pre_close': 5.0}]

# %%
code = '000001'
name_result = [d for d in DB_CONN['basic'].find({'code':code},
      projection={'name':True, 'date':True, '_id':False})]
name_result
# Out:
# [{'date': '2017-08-24', 'name': '平安银行'},
#  {'date': '2017-08-25', 'name': '平安银行'},
#  {'date': '2017-08-28', 'name': '平安银行'},
#  {'date': '2017-08-29', 'name': '平安银行'},
#  {'date': '2017-08-30', 'name': '平安银行'},
#  {'date': '2017-08-31', 'name': '平安银行'},
#  {'date': '2017-09-01', 'name': '平安银行'},
#  {'date': '2017-09-04', 'name': '平安银行'},
#  {'date': '2017-09-05', 'name': '平安银行'},
#  {'date': '2017-09-06', 'name': '平安银行'},
#  {'date': '2017-09-07', 'name': '平安银行'},
#  {'date': '2017-09-08', 'name': '平安银行'},
#  {'date': '2017-09-11', 'name': '平安银行'},
#  {'date': '2017-09-12', 'name': '平安银行'},
#  {'date': '2017-09-13', 'name': '平安银行'},
#  {'date': '2017-09-14', 'name': '平安银行'},
#  {'date': '2017-09-15', 'name': '平安银行'},
#  {'date': '2017-09-18', 'name': '平安银行'},
#  {'date': '2017-09-19', 'name': '平安银行'},
#  {'date': '2017-09-20', 'name': '平安银行'},
#  {'date': '2017-09-21', 'name': '平安银行'},
#  {'date': '2017-09-22', 'name': '平安银行'},
#  {'date': '2017-09-25', 'name': '平安银行'},
#  {'date': '2017-09-26', 'name': '平安银行'},
#  {'date': '2017-09-27', 'name': '平安银行'},
#  {'date': '2017-09-28', 'name': '平安银行'},
#  {'date': '2017-09-29', 'name': '平安银行'},
#  {'date': '2017-10-09', 'name': '平安银行'},
#  {'date': '2017-10-10', 'name': '平安银行'},
#  {'date': '2017-10-11', 'name': '平安银行'},
#  {'date': '2017-10-12', 'name': '平安银行'},
#  {'date': '2017-10-13', 'name': '平安银行'},
#  {'date': '2017-10-16', 'name': '平安银行'},
#  {'date': '2017-10-17', 'name': '平安银行'},
#  {'date': '2017-10-18', 'name': '平安银行'},
#  {'date': '2017-10-19', 'name': '平安银行'},
#  {'date': '2017-10-20', 'name': '平安银行'},
#  {'date': '2017-10-23', 'name': '平安银行'},
#  {'date': '2017-10-24', 'name': '平安银行'},
#  {'date': '2017-10-25', 'name': '平安银行'},
#  {'date': '2017-10-26', 'name': '平安银行'},
#  {'date': '2017-10-27', 'name': '平安银行'},
#  {'date': '2017-10-30', 'name': '平安银行'},
#  {'date': '2017-10-31', 'name': '平安银行'},
#  {'date': '2017-11-01', 'name': '平安银行'},
#  {'date': '2017-11-02', 'name': '平安银行'},
#  {'date': '2017-11-03', 'name': '平安银行'},
#  {'date': '2017-11-06', 'name': '平安银行'},
#  {'date': '2017-11-07', 'name': '平安银行'},
#  {'date': '2017-11-08', 'name': '平安银行'},
#  {'date': '2017-11-09', 'name': '平安银行'},
#  {'date': '2017-11-10', 'name': '平安银行'},
#  {'date': '2017-11-13', 'name': '平安银行'},
#  {'date': '2017-11-14', 'name': '平安银行'},
#  {'date': '2017-11-15', 'name': '平安银行'},
#  {'date': '2017-11-16', 'name': '平安银行'},
#  {'date': '2017-11-17', 'name': '平安银行'},
#  {'date': '2017-11-20', 'name': '平安银行'},
#  {'date': '2017-11-21', 'name': '平安银行'},
#  {'date': '2017-11-22', 'name': '平安银行'},
#  {'date': '2017-11-23', 'name': '平安银行'},
#  {'date': '2017-11-24', 'name': '平安银行'},
#  {'date': '2017-11-27', 'name': '平安银行'},
#  {'date': '2017-11-28', 'name': '平安银行'},
#  {'date': '2017-11-29', 'name': '平安银行'},
#  {'date': '2017-11-30', 'name': '平安银行'},
#  {'date': '2017-12-01', 'name': '平安银行'},
#  {'date': '2017-12-04', 'name': '平安银行'},
#  {'date': '2017-12-05', 'name': '平安银行'},
#  {'date': '2017-12-06', 'name': '平安银行'},
#  {'date': '2017-12-07', 'name': '平安银行'},
#  {'date': '2017-12-08', 'name': '平安银行'},
#  {'date': '2017-12-11', 'name': '平安银行'},
#  {'date': '2017-12-12', 'name': '平安银行'},
#  {'date': '2017-12-13', 'name': '平安银行'},
#  {'date': '2017-12-14', 'name': '平安银行'},
#  {'date': '2017-12-15', 'name': '平安银行'},
#  {'date': '2017-12-18', 'name': '平安银行'},
#  {'date': '2017-12-19', 'name': '平安银行'},
#  {'date': '2017-12-20', 'name': '平安银行'},
#  {'date': '2017-12-21', 'name': '平安银行'},
#  {'date': '2017-12-22', 'name': '平安银行'},
#  {'date': '2017-12-25', 'name': '平安银行'},
#  {'date': '2017-12-26', 'name': '平安银行'},
#  {'date': '2017-12-27', 'name': '平安银行'},
#  {'date': '2017-12-28', 'name': '平安银行'},
#  {'date': '2017-12-29', 'name': '平安银行'}]

# %%
df = ts.get_stock_basics('2016-08-09')

# %%
df.loc[code, :]
# Out:
# name                    华控赛格
# industry                 元器件
# area                      深圳
# pe                         0
# outstanding          89667.1
# totals                100667
# totalAssets          71611.4
# liquidAssets         34903.4
# fixedAssets          19342.2
# reserved              119427
# reservedPerShare        1.19
# esp                   -0.013
# bvps                     0.6
# pb                     15.74
# timeToMarket        19970611
# Name: 000068, dtype: object

# %%
check_data = QA.QA_fetch_stock_day_adv(code, start, end).data

# %%
check_data.head(10)
# Out:
#                     open   high    low  close   volume      amount
# date       code
# 2015-01-06 002553  12.20  12.85  12.00  12.49  54887.0  68584352.0
# 2015-01-07 002553  12.50  12.50  12.15  12.23  32313.0  39639268.0
# 2015-01-08 002553  12.21  12.37  12.02  12.34  27120.0  33100818.0
# 2015-01-09 002553  12.39  12.39  12.15  12.17  17274.0  21163628.0
# 2015-01-12 002553  12.17  12.17  11.80  11.80  18501.0  22012400.0
# 2015-01-13 002553  11.80  11.98  11.80  11.93   9457.0  11252456.0
# 2015-01-14 002553  11.90  11.99  11.83  11.91   9990.0  11886320.0
# 2015-01-15 002553  11.90  11.99  11.90  11.90  12274.0  14652570.0
# 2015-01-16 002553  11.90  12.18  11.89  12.09  14776.0  17808918.0
# 2015-01-19 002553  12.00  12.24  11.80  11.93  27029.0  32458670.0

# %% [markdown]
# 这个bug的原因是基础数据获取的不够完整,不是每一个交易日都有数据

# %%
'603214' in df.index
# Out:
# Index(['002939', '000068', '300083', '002076', '600758', '002708', '600173',
#        '601162', '000622', '002377',
#        ...
#        '603386', '600298', '603579', '002942', '002941', '002070', '000693',
#        '600680', '600401', '300674'],
#       dtype='object', name='code', length=3559)

# %%
df.loc['603214',:]
# Out:
# name                     爱婴室
# industry                  百货
# area                      上海
# pe                     41.32
# outstanding             0.25
# totals                     1
# totalAssets           136925
# liquidAssets          119606
# fixedAssets          6993.16
# reserved               41564
# reservedPerShare        4.16
# esp                     0.72
# bvps                    8.31
# pb                      4.35
# timeToMarket        20180330
# undp                 30020.1
# perundp                    3
# rev                        0
# profit                     0
# gpr                    27.32
# npr                     4.32
# holders                19012
# Name: 603214, dtype: object

# %%
_date
# Out:
# '2016-08-10'

# %%
code
# Out:
# '600781'

# %%
DB_CONN['basic'].find_one({'code':code, 'date':_date},
     projection={'name':True, '_id':False})['name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-e1cc15b5944e> in <module>()
#       1 DB_CONN['basic'].find_one({'code':code, 'date':_date},
# ----> 2      projection={'name':True, '_id':False})['name']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
test_cursor = DB_CONN['basic'].find({'code':code},
                      projection={'name':True, 'date':True, '_id':False})

# %%
result = [i for i in test_cursor]

# %%
result[:10]
# Out:
# [{'date': '2016-08-09', 'name': '通威股份'},
#  {'date': '2016-08-11', 'name': '通威股份'},
#  {'date': '2016-08-15', 'name': '通威股份'},
#  {'date': '2016-08-16', 'name': '通威股份'},
#  {'date': '2016-08-17', 'name': '通威股份'},
#  {'date': '2016-08-18', 'name': '通威股份'},
#  {'date': '2016-08-22', 'name': '通威股份'},
#  {'date': '2016-08-23', 'name': '通威股份'},
#  {'date': '2016-08-24', 'name': '通威股份'},
#  {'date': '2016-08-25', 'name': '通威股份'}]

# %%
# test_cursor = DB_CONN['basic'].find({'code':code},
#                       projection={'name':True, 'date':True, '_id':False})
# result = [i for i in test_cursor]
# result

# %%
DB_CONN['basic'].find_one({'code':code},
                      projection={'name':True, 'date':True, '_id':False})
# Out:
# {'date': '2016-08-09', 'name': '辅仁药业'}

# %%
# daily_cursor = DB_CONN['daily'].find(
#             {'code':code, 'date':{'$lte': end, '$gte': timeToMarket}, 'index':False},
#             projection={'code':True, 'date':True, 'pre_close':True, '_id':False})
# dailies = [i for i in daily_cursor]
# dailies

# %%
df = pd.read_excel('ipo_info.xlsx', header=0, dtype={'code':str})

# %%
df.head()
# Out:
#      code  name  issueprice timeToMarket
# 0  000001  平安银行        40.0   1989-03-10
# 1  000002   万科A         1.0   1988-12-28
# 2  000004  国农科技         1.0   1989-12-23
# 3  000005  世纪星源        10.0   1990-02-28
# 4  000006  深振业A        10.0   1991-12-01
