# %%
import numpy as np
import pandas as pd
from database import DB_CONN, UpdateOne

# %%
excel_name = 'data/stock_basic.xlsx'

# %%
df_2015 = pd.read_excel(excel_name, 1, header=0, index_col=[0,1], dtype={})

# %%
df_2015.head()
# Out:
#              2015-01-05 2015-01-06 2015-01-07 2015-01-08 2015-01-09  \
# 1 平安银行 是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 2 万科A  是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 4 国农科技 是否ST           否          否          否          否          否
#
#              2015-01-12 2015-01-13 2015-01-14 2015-01-15 2015-01-16  \
# 1 平安银行 是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 2 万科A  是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 4 国农科技 是否ST           否          否          否          否          否
#
#                 ...     2015-12-18 2015-12-21 2015-12-22 2015-12-23  \
# 1 平安银行 是否ST     ...              否          否          否          否
# ...

# %%
df_test = pd.read_excel('data/test.xlsx', header=0, dtype={'code':str})
df_test = df_test.set_index(['code','state'])
df_test.columns = df_test.columns.astype(np.datetime64)
df_test.columns = df_test.columns.to_period('D')
df_test.columns = df_test.columns.astype('str')

# %%
df_test
# Out:
#              2015-01-05 2015-01-06 2015-01-07 2015-01-08 2015-01-09  \
# code   state
# 000001 是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 000002 是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 000004 是否ST           否          否          否          否          否
#
#              2015-01-12 2015-01-13 2015-01-14 2015-01-15 2015-01-16  \
# code   state
# 000001 是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 000002 是否ST           否          否          否          否          否
#        是否*ST          否          否          否          否          否
# 000004 是否ST           否          否          否          否          否
#
#                 ...     2015-12-18 2015-12-21 2015-12-22 2015-12-23  \
# code   state    ...
# ...

# %%
df_test.xs(['000001'])['2015-01-05']['是否ST']
# Out:
# '否'

# %%
df_test.xs(['000001'])['2015-01-05']['是否*ST']
# Out:
# '否'

# %%
def is_st(*series):
    flag = False
    for i in series:
        if i == '是':
            flag = True
    return flag

# %%
df_test.groupby(by=['code', 'name']).apply(is_st)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-50-09baade33f0e> in is_st(*series)
# ...
