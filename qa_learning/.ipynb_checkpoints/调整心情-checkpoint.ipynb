# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import statsmodels.api as sm
# import tushare as ts
import QUANTAXIS as QA
import talib as ta
import datetime, time
from tqdm import tqdm_notebook

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %%
index_all = QA.QA_fetch_index_list_adv()
index_all.to_csv('data/index.csv', encoding='utf_8_sig')

# %%
index_list=['880490','880916','000025','000807',
            '399989','000934','000001','880230','880911','880202']
data_min = QA.QA_fetch_index_min_adv(index_all.index.tolist(), 
                                     '2019-01-01', '2019-02-01', '5min')
index_vol_sorted = data_min.volume.groupby(level=1).mean().\
sort_values(ascending=False)
index_all.loc[index_vol_sorted.index[51:100]].name
index_range_sorted = data_min.price.groupby(level=1).apply(lambda x:(x/x[0])).\
groupby(level=1).std().sort_values()
index_range_sorted.head(20)
index_all.loc[index_range_sorted.index[:20]].name

# %% [markdown]
# 002366

# %%
code = '002366'
start = '2018-01-01'
end = '2018-12-31'

# %%
data_min = QA.QA_fetch_stock_min_adv(code, start, end, '15min')

# %%
data_min = data_min.to_qfq()

# %%
# QA.QA_indicator_RSI()

# %%
ind = data_min.add_func(QA.QA_indicator_RSI)

# %%
# ind.index = ind.index.droplevel(1)
# 我需要看下出信号的点在实际k线图上是什么样的

# %%
ind.xs(code, level=1).RSI1.plot();

# %%
data_min.kline_echarts()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="620a6f455fb74217bdae74929d5877af" style="width:1360px;height:700px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_620a6f455fb74217bdae74929d5877af = echarts.init(document.getElementById('620a6f455fb74217bdae74929d5877af'), 'light', {renderer: 'canvas'});
# function kline_tooltip_formatter(params) {
#     var text;
#     text = ((((((((((((params[0].seriesName + "<br/>") + "- open:") + params[0].data[1]) + "<br/>") + "- close:") + params[0].data[2]) + "<br/>") + "- lowest:") + params[0].data[3]) + "<br/>") + "- highest:") + params[0].data[4]);
#     return text;
# }
#
# var option_620a6f455fb74217bdae74929d5877af = {
#     "title": [
#         {
#             "text": "CodePackage_qfq_stock_min",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1509605,
#     "tooltip": {
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": kline_tooltip_formatter,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "002366",
#             "data": [
#                 [
#                     24.22092037350331,
#                     24.883018156051136,
#                     24.22092037350331,
#                     25.495705656319274
#                 ],
#                 [
#                     24.883018156051136,
#                     24.705141139844258,
#                     24.60632057528488,
#                     25.09054134162583
#                 ],
#                 [
#                     24.74466936566801,
#                     24.83360787377145,
#                     24.60632057528488,
#                     25.09054134162583
#                 ],
#                 [
#                     24.83360787377145,
#                     24.85337198668332,
#                     24.823725817315513,
#                     25.545115938598965
#                 ],
#                 [
#                     24.85337198668332,
#                     24.932428438330827,
#                     24.813843760859573,
#                     25.100423398081766
#                 ],
#                 [
#                     25.100423398081766,
#                     24.84348993022739,
#                     24.823725817315513,
#                     25.189361906185205
#                 ],
#                 [
#                     24.83360787377145,
#                     25.17947984972927,
#                     24.83360787377145,
#                     25.495705656319274
#                 ],
#                 [
#                     25.189361906185205,
#                     24.94231049478676,
#                     24.902782268963012,
#                     25.199243962641145
#                 ],
#                 [
#                     24.94231049478676,
#                     25.070777228713954,
#                     24.94231049478676,
#                     25.17947984972927
#                 ],
#                 [
#                     25.08065928516989,
#                     25.04113105934614,
#                     25.0312490028902,
#                     25.120187510993645
#                 ],
#                 [
#                     25.060895172258014,
#                     25.04113105934614,
#                     24.9521925512427,
#                     25.070777228713954
#                 ],
#                 [
#                     25.04113105934614,
#                     24.99172077706645,
#                     24.981838720610515,
#                     25.070777228713954
#                 ],
#                 [
#                     24.981838720610515,
#                     24.883018156051136,
#                     24.85337198668332,
#                     25.00160283352239
#                 ],
#                 [
#                     24.85337198668332,
#                     24.635966744652695,
#                     24.61620263174082,
#                     24.883018156051136
#                 ],
#                 [
#                     24.61620263174082,
#                     24.458089728445817,
#                     24.329622994518626,
#                     24.61620263174082
#                 ],
#                 [
#                     24.458089728445817,
#                     24.635966744652695,
#                     24.38891533325425,
#                     24.9521925512427
#                 ],
#                 [
#                     24.83360787377145,
#                     25.0312490028902,
#                     24.83360787377145,
#                     25.189361906185205
#                 ],
#                 [
#                     25.0312490028902,
#                     25.011484889978327,
#                     24.922546381874888,
#                     25.100423398081766
#                 ],
#                 [
#                     25.011484889978327,
#                     24.784197591491758,
#                     24.754551422123946,
#                     25.021366946434267
#                 ],
#                 [
#                     24.77431553503582,
#                     24.754551422123946,
#                     24.705141139844258,
#                     24.803961704403637
#                 ],
#                 [
#                     24.754551422123946,
#                     24.813843760859573,
#                     24.705141139844258,
#                     24.83360787377145
#                 ],
#                 [
#                     24.803961704403637,
#                     24.576674405917068,
#                     24.56679234946113,
#                     24.83360787377145
#                 ],
#                 [
#                     24.56679234946113,
#                     24.635966744652695,
#                     24.547028236549256,
#                     24.74466936566801
#                 ],
#                 [
#                     24.645848801108635,
#                     24.705141139844258,
#                     24.635966744652695,
#                     24.74466936566801
#                 ],
#                 [
#                     24.705141139844258,
#                     24.823725817315513,
#                     24.705141139844258,
#                     24.83360787377145
#                 ],
#                 [
#                     24.813843760859573,
#                     24.971956664154575,
#                     24.794079647947697,
#                     25.04113105934614
#                 ],
#                 [
#                     24.971956664154575,
#                     25.139951623905517,
#                     24.96207460769864,
#                     25.159715736817393
#                 ],
#                 [
#                     25.130069567449578,
#                     25.238772188464893,
#                     25.130069567449578,
#                     25.32771069656833
#                 ],
#                 [
#                     25.248654244920832,
#                     25.130069567449578,
#                     25.05101311580208,
#                     25.268418357832708
#                 ],
#                 [
#                     25.130069567449578,
#                     25.199243962641145,
#                     25.130069567449578,
#                     25.228890132008956
#                 ],
#                 [
#                     25.199243962641145,
#                     25.456177430495526,

# %%
data_min.close.xs(code, level=1)['2018-10':'2018-12'].plot();

# %%
ind.xs(code, level=1)['2018-05'].RSI1.plot();

# %%
data_close = data_min.close.xs(code, level=1)

# %%
data_close.head()
# Out:
# datetime
# 2018-05-07 09:45:00    24.883018
# 2018-05-07 10:00:00    24.705141
# 2018-05-07 10:15:00    24.833608
# 2018-05-07 10:30:00    24.853372
# 2018-05-07 10:45:00    24.932428
# Name: close, dtype: float64

# %%
ind_min = (data_close <= data_close.shift(1)) &\
(data_close.shift(1) <= data_close.shift(2)) &\
(data_close <= data_close.shift(-1)) &\
(data_close.shift(-1) <= data_close.shift(-2))

# %%
ind_min.values
# Out:
# DatetimeIndex(['2018-05-07 09:45:00', '2018-05-07 10:00:00',
#                '2018-05-07 10:15:00', '2018-05-07 10:30:00',
#                '2018-05-07 10:45:00', '2018-05-07 11:00:00',
#                '2018-05-07 11:15:00', '2018-05-07 11:30:00',
#                '2018-05-07 13:15:00', '2018-05-07 13:30:00',
#                ...
#                '2018-12-28 11:15:00', '2018-12-28 11:30:00',
#                '2018-12-28 13:15:00', '2018-12-28 13:30:00',
#                '2018-12-28 13:45:00', '2018-12-28 14:00:00',
#                '2018-12-28 14:15:00', '2018-12-28 14:30:00',
#                '2018-12-28 14:45:00', '2018-12-28 15:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=2608, freq=None)

# %%
plt.rcParams['figure.figsize'] = [48, 12]
x = ind.xs(code, level=1)[ind_min].RSI1.index
y = ind.xs(code, level=1)[ind_min].RSI1.values
ind.xs(code, level=1).RSI1.plot();
plt.scatter(x, y, c='b');

# %%
plt.rcParams['figure.figsize'] = [24, 12]
x = ind.xs(code, level=1)[ind_min]['2018-05'].RSI1.index
y = ind.xs(code, level=1)[ind_min]['2018-05'].RSI1.values
ind.xs(code, level=1)['2018-05'].RSI1.plot();
plt.scatter(x, y, c='b');

# %%
# ind.xs(code, level=1)[ind_min].plot.scatter();

# %%
ind.xs(code, level=1)[ind_min].describe()
# Out:
#              RSI1        RSI2        RSI3
# count  235.000000  235.000000  235.000000
# mean    37.313604   40.068371   35.848558
# std     18.601349   14.642814   20.193253
# min      1.240260    5.381190    0.515141
# 25%     21.956644   30.076183   18.981715
# 50%     38.791205   41.801225   35.486986
# 75%     50.589337   51.524198   49.093061
# max     79.590207   64.470353   85.592589

# %%
ind.xs(code, level=1)[ind_min].median()
# Out:
# RSI1    38.791205
# RSI2    41.801225
# RSI3    35.486986
# dtype: float64

# %%
ind.xs(code, level=1)[ind_min].hist(bins=20);

# %%
num_min, interval_min, _ = plt.hist(ind.xs(code, level=1)[ind_min].RSI1, bins=20);

# %%
print(interval_min[4], interval_min[5])
# Out:
# 16.9102496376 20.8277469587

# %%
(interval_min[4] + interval_min[5]) / 2
# Out:
# 18.868998298150963

# %%
ind_max = (data_close >= data_close.shift(1)) &\
(data_close.shift(1) >= data_close.shift(2)) &\
(data_close >= data_close.shift(-1)) &\
(data_close.shift(-1) >= data_close.shift(-2))

# %%
ind.xs(code, level=1)[ind_max].describe()
# Out:
#              RSI1        RSI2        RSI3
# count  222.000000  222.000000  222.000000
# mean    48.458292   45.131905   50.451491
# std     21.447265   16.179141   23.622434
# min      3.715286    8.875466    2.423205
# 25%     34.981819   34.241412   36.554566
# 50%     52.199924   47.077599   54.047433
# 75%     63.734714   57.218422   67.755885
# max     87.213993   78.212541   90.463796

# %%
ind.xs(code, level=1)[ind_max].median()
# Out:
# RSI1    52.199924
# RSI2    47.077599
# RSI3    54.047433
# dtype: float64

# %%
ind.xs(code, level=1)[ind_max].hist(bins=20);

# %%
num_max, interval_max, _ = plt.hist(ind.xs(code, level=1)[ind_max].RSI1, bins=20);

# %%
interval_max
# Out:
# array([  3.71528585,   7.89022123,  12.06515661,  16.24009199,
#         20.41502737,  24.58996275,  28.76489813,  32.93983351,
#         37.11476889,  41.28970427,  45.46463965,  49.63957503,
#         53.81451041,  57.98944579,  62.16438117,  66.33931655,
#         70.51425193,  74.68918732,  78.8641227 ,  83.03905808,  87.21399346])

# %%
(interval_max[13] + interval_max[14]) / 2
# Out:
# 60.076913484320727

# %%
ind_atr = data_min.add_func(QA.QA_indicator_ATR, 80)

# %%
ind_atr.tail()
# Out:
#                               TR       ATR
# datetime            code
# 2018-12-28 14:00:00 002366  0.04  0.100375
# 2018-12-28 14:15:00 002366  0.07  0.100375
# 2018-12-28 14:30:00 002366  0.08  0.100125
# 2018-12-28 14:45:00 002366  0.08  0.099250
# 2018-12-28 15:00:00 002366  0.07  0.099125

# %%
ind_atr.describe()
# Out:
#                 TR          ATR
# count  2607.000000  2528.000000
# mean      0.139939     0.138880
# std       0.118962     0.031871
# min       0.000000     0.080045
# 25%       0.070000     0.113397
# 50%       0.110000     0.136746
# 75%       0.167995     0.158000
# max       1.976411     0.237911
