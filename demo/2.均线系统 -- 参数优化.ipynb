# %% [markdown]
# ## initial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import statsmodels.api as sm
import QUANTAXIS as QA
import talib as ta
import datetime, time

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
start = '2000-01-01'
end = '2016-05-12'

# %%
code = '002149'

# %%
data = QA.QA_fetch_stock_day_adv(code, start, end)

# %%
data_hfq = data.to_hfq()

# %% [markdown]
# ## 这个是有未来函数！！！

# %%
def MA_JCSC(dataframe, SHORT=5, LONG=10):
    """
    短时均线上传长时均线，买入信号参考；
    短时均线下穿长时均线，卖出信号参考.
    """
    CLOSE = dataframe.close
    MA_SHORT = CLOSE.rolling(SHORT).mean()
    MA_LONG = CLOSE.rolling(LONG).mean()
    
    CROSS_JC = QA.CROSS(MA_SHORT, MA_LONG)
    CROSS_SC = QA.CROSS(MA_LONG, MA_SHORT)
    
    return pd.DataFrame({'MA_SHORT':MA_SHORT, 'MA_LONG':MA_LONG,
                        'CROSS_JC':CROSS_JC, 'CROSS_SC':CROSS_SC})

# %%
Account = QA.QA_Account()
Broker = QA.QA_BacktestBroker()

# %%
Account.reset_assets(5e+5)
Account.account_cookie = 'MA_JCSC'

# %% [markdown]
# ## 一些尝试

# %%
ind = data_hfq.add_func(MA_JCSC, 5, 10)

# %%
# ind.loc[('2007-08-15', '002149'), 'CROSS_JC'][0]
# Out:
# 0

# %%
QA.QA_indicator_ATR??

# %%
def backtest(dataframe, ind, Account, Broker, start, end):
    data_forbacktest = dataframe.select_time(start, end)
    
    for items in data_forbacktest.panel_gen:
    # item 为每只股票
    for item in items.security_gen:
        # daily_ind为每只股票对应的指标
        daily_ind = ind.loc[item.index]
        # 买入信号判断
        if daily_ind.CROSS_JC.iloc[0] > 0:
            # 下单：1.code;2.time;3.amount or price model;
            # 4. Buy or sell; 5.set price if price model;
            # 6.
            order = Account.send_order(
                code = item.code[0],
                time = item.date[0],
                amount = 2500,
                towards = QA.ORDER_DIRECTION.BUY,
                price = 0,
                order_model = QA.ORDER_MODEL.CLOSE,
                amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                )
            # Broker receive order: order and data
            Broker.receive_order(QA.QA_Event(order=order, market_data=item))
            
            # trade message
            trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
            # 233, order后面会自己tab出'account_cookie',是因为上一行中的
            # Account.account_cookie
            # result ?
            res = trade_mes.loc[order.account_cookie, order.realorder_id]
            # 交易id、价格、数量和时间
            order.trade(res.trade_id, res.trade_price, res.trade_amount,
                       res.trade_time)
        elif daily_ind.CROSS_SC.iloc[0] > 0:
            if Account.sell_available.get(item.code[0], 0)>0:
                order = Account.send_order(
                    code = item.code[0],
                    time = item.date[0],
                    amount = Account.sell_available.get(item.code[0], 0),
                    towards = QA.ORDER_DIRECTION.SELL,
                    price = 0,
                    order_model = QA.ORDER_MODEL.MARKET,
                    amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                    )
                Broker.receive_order(QA.QA_Event(order=order, market_data=item))
                
                trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                res = trade_mes.loc[order.account_cookie, order.realorder_id]
                order.trade(res.trade_id, res.trade_price, res.trade_amount,
                           res.trade_time)
    Account.settle()

# %%
data_forbacktest = data.select_time('2007-08-10', '2014-12-31')

for items in data_forbacktest.panel_gen:
    # item 为每只股票
    for item in items.security_gen:
        # daily_ind为每只股票对应的指标
        daily_ind = ind.loc[item.index]
        # 买入信号判断
        if daily_ind.CROSS_JC.iloc[0] > 0:
            # 下单：1.code;2.time;3.amount or price model;
            # 4. Buy or sell; 5.set price if price model;
            # 6.
            order = Account.send_order(
                code = item.code[0],
                time = item.date[0],
                amount = 2500,
                towards = QA.ORDER_DIRECTION.BUY,
                price = 0,
                order_model = QA.ORDER_MODEL.CLOSE,
                amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                )
            # Broker receive order: order and data
            Broker.receive_order(QA.QA_Event(order=order, market_data=item))
            
            # trade message
            trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
            # 233, order后面会自己tab出'account_cookie',是因为上一行中的
            # Account.account_cookie
            # result ?
            res = trade_mes.loc[order.account_cookie, order.realorder_id]
            # 交易id、价格、数量和时间
            order.trade(res.trade_id, res.trade_price, res.trade_amount,
                       res.trade_time)
        elif daily_ind.CROSS_SC.iloc[0] > 0:
            if Account.sell_available.get(item.code[0], 0)>0:
                order = Account.send_order(
                    code = item.code[0],
                    time = item.date[0],
                    amount = Account.sell_available.get(item.code[0], 0),
                    towards = QA.ORDER_DIRECTION.SELL,
                    price = 0,
                    order_model = QA.ORDER_MODEL.MARKET,
                    amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                    )
                Broker.receive_order(QA.QA_Event(order=order, market_data=item))
                
                trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                res = trade_mes.loc[order.account_cookie, order.realorder_id]
                order.trade(res.trade_id, res.trade_price, res.trade_amount,
                           res.trade_time)
    Account.settle()
# Out:
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal

# %%
_risk = QA.QA_Risk(Account)
_max_dropback = _risk.max_dropback
_target = _risk.profit / _risk.max_dropback
_df = pd.DataFrame({'N1':N1, 'N2':N2, 'target':_target})
df_result = pd.concat([df_result, _df], axis=0)

# %%
Risk = QA.QA_Risk(Account)

# %%
Risk.max_dropback
# Out:
# 0.08

# %%
Risk.profit
# Out:
# -0.01

# %%
Risk.plot_assets_curve();

# %%
len(range(10, 31, 3))
# Out:
# 7

# %%
data.date[-1]
# Out:
# Timestamp('2016-05-12 00:00:00')

# %%
df_result = pd.DataFrame()
count = 0
for N1 in range(5, 21, 2):
    for N2 in range(10, 31, 3):
        ind = data_hfq.add_func(MA_JCSC, N1, N2)
        Account.reset_assets(5e+5)
        
        data_forbacktest = data.select_time('2007-08-10', '2014-12-31')
        last_date = data_forbacktest.date[-1]
        for items in data_forbacktest.panel_gen:
            # item 为每只股票
            for item in items.security_gen:
                # daily_ind为每只股票对应的指标
                daily_ind = ind.loc[item.index]
                # 买入信号判断
                if daily_ind.CROSS_JC.iloc[0] > 0:
                    # 下单：1.code;2.time;3.amount or price model;
                    # 4. Buy or sell; 5.set price if price model;
                    # 6.
                    order = Account.send_order(
                        code = item.code[0],
                        time = item.date[0],
                        amount = 2500,
                        towards = QA.ORDER_DIRECTION.BUY,
                        price = 0,
                        order_model = QA.ORDER_MODEL.CLOSE,
                        amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                        )
                    # Broker receive order: order and data
                    Broker.receive_order(QA.QA_Event(order=order, market_data=item))

                    # trade message
                    trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                    # 233, order后面会自己tab出'account_cookie',是因为上一行中的
                    # Account.account_cookie
                    # result ?
                    res = trade_mes.loc[order.account_cookie, order.realorder_id]
                    # 交易id、价格、数量和时间
                    order.trade(res.trade_id, res.trade_price, res.trade_amount,
                               res.trade_time)
                elif daily_ind.CROSS_SC.iloc[0] > 0:
                    if Account.sell_available.get(item.code[0], 0)>0:
                        order = Account.send_order(
                            code = item.code[0],
                            time = item.date[0],
                            amount = Account.sell_available.get(item.code[0], 0),
                            towards = QA.ORDER_DIRECTION.SELL,
                            price = 0,
                            order_model = QA.ORDER_MODEL.MARKET,
                            amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                            )
                        Broker.receive_order(QA.QA_Event(order=order, market_data=item))

                        trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                        res = trade_mes.loc[order.account_cookie, order.realorder_id]
                        order.trade(res.trade_id, res.trade_price, res.trade_amount,
                                   res.trade_time)
                if item.date[0] == last_date:
                    if Account.sell_available.get(item.code[0], 0)>0:
                        order = Account.send_order(
                            code = item.code[0],
                            time = item.date[0],
                            amount = Account.sell_available.get(item.code[0], 0),
                            towards = QA.ORDER_DIRECTION.SELL,
                            price = 0,
                            order_model = QA.ORDER_MODEL.MARKET,
                            amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                            )
                        Broker.receive_order(QA.QA_Event(order=order, market_data=item))

                        trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                        res = trade_mes.loc[order.account_cookie, order.realorder_id]
                        order.trade(res.trade_id, res.trade_price, res.trade_amount,
                                   res.trade_time)
            Account.settle()
            
#         _risk = QA.QA_Risk(Account)
#         _max_dropback = _risk.max_dropback
#         _target = _risk.profit / _risk.max_dropback
        try:
            _df = pd.DataFrame({'N1':N1, 'N2':N2, 'target':Account.cash}, index=[count])
            df_result = pd.concat([df_result, _df], axis=0)
        except:
            pass

# %%
Account.cash
# Out:
# [500000.0]

# %% [markdown]
# ### 使用随机搜索参数空间

# %%
N1 = np.random.choice(range(5,21))
N2 = np.random.choice(range(N1+1, 31))
# Out:
# 15

# %%
N1 = 11
N2 = 23

# %%
df_result = pd.DataFrame()
count = 0
while count < 5:
    count += 1
    N1 = np.random.choice(range(5,21))
    N2 = np.random.choice(range(N1+1, 31))
    ind = data_hfq.add_func(MA_JCSC, N1, N2)
    Account.reset_assets(5e+5)

    data_forbacktest = data.select_time('2007-08-10', '2014-12-31')
    last_date = data_forbacktest.date[-1]
    for items in data_forbacktest.panel_gen:
        # item 为每只股票
        for item in items.security_gen:
            # daily_ind为每只股票对应的指标
            daily_ind = ind.loc[item.index]
            # 买入信号判断
            if daily_ind.CROSS_JC.iloc[0] > 0:
                # 下单：1.code;2.time;3.amount or price model;
                # 4. Buy or sell; 5.set price if price model;
                # 6.
                order = Account.send_order(
                    code = item.code[0],
                    time = item.date[0],
                    amount = 2500,
                    towards = QA.ORDER_DIRECTION.BUY,
                    price = 0,
                    order_model = QA.ORDER_MODEL.CLOSE,
                    amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                    )
                # Broker receive order: order and data
                Broker.receive_order(QA.QA_Event(order=order, market_data=item))

                # trade message
                trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                # 233, order后面会自己tab出'account_cookie',是因为上一行中的
                # Account.account_cookie
                # result ?
                res = trade_mes.loc[order.account_cookie, order.realorder_id]
                # 交易id、价格、数量和时间
                order.trade(res.trade_id, res.trade_price, res.trade_amount,
                           res.trade_time)
            elif daily_ind.CROSS_SC.iloc[0] > 0:
                if Account.sell_available.get(item.code[0], 0)>0:
                    order = Account.send_order(
                        code = item.code[0],
                        time = item.date[0],
                        amount = Account.sell_available.get(item.code[0], 0),
                        towards = QA.ORDER_DIRECTION.SELL,
                        price = 0,
                        order_model = QA.ORDER_MODEL.MARKET,
                        amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                        )
                    Broker.receive_order(QA.QA_Event(order=order, market_data=item))

                    trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                    res = trade_mes.loc[order.account_cookie, order.realorder_id]
                    order.trade(res.trade_id, res.trade_price, res.trade_amount,
                               res.trade_time)
            if item.date[0] == last_date:
                if Account.sell_available.get(item.code[0], 0)>0:
                    order = Account.send_order(
                        code = item.code[0],
                        time = item.date[0],
                        amount = Account.sell_available.get(item.code[0], 0),
                        towards = QA.ORDER_DIRECTION.SELL,
                        price = 0,
                        order_model = QA.ORDER_MODEL.MARKET,
                        amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                        )
                    Broker.receive_order(QA.QA_Event(order=order, market_data=item))

                    trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                    res = trade_mes.loc[order.account_cookie, order.realorder_id]
                    order.trade(res.trade_id, res.trade_price, res.trade_amount,
                               res.trade_time)
        Account.settle()

#         _risk = QA.QA_Risk(Account)
#         _max_dropback = _risk.max_dropback
#         _target = _risk.profit / _risk.max_dropback
    try:
        final_cash = Account.history_table.cash.iloc[-1]
        _df = pd.DataFrame({'N1':N1, 'N2':N2, 'target':final_cash}, index=[count])
        df_result = pd.concat([df_result, _df], axis=0)
    except:
        pass
# Out:
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal

# %%
df_result
# Out:
#    N1  N2        target
# 1  17  22  536829.43750
# 2  19  20  534783.78125
# 3  12  13  483310.43750
# 4  15  20  511617.97500
# 5  19  30  497745.14375

# %%
df_result
# Out:
#    N1  N2        target
# 1  18  25  525946.56875
# 2  19  20  534783.78125
# 3  15  16  488426.40625
# 4   5  30  493227.21875
# 5   5   8  499626.70625

# %%
Account.cash_table[Account.cash_table.cash.isna()].head()
# Out:
#                                     cash             datetime       date  \
# datetime            account_cookie
# 2011-01-25 00:00:00 MA_JCSC         None  2011-01-25 00:00:00 2011-01-25
# 2011-02-21 00:00:00 MA_JCSC         None  2011-02-21 00:00:00 2011-02-21
# 2011-02-22 00:00:00 MA_JCSC         None  2011-02-22 00:00:00 2011-02-22
# 2011-02-23 00:00:00 MA_JCSC         None  2011-02-23 00:00:00 2011-02-23
# 2011-03-23 00:00:00 MA_JCSC         None  2011-03-23 00:00:00 2011-03-23
#
#                                    account_cookie
# datetime            account_cookie
# 2011-01-25 00:00:00 MA_JCSC               MA_JCSC
# 2011-02-21 00:00:00 MA_JCSC               MA_JCSC
# 2011-02-22 00:00:00 MA_JCSC               MA_JCSC
# 2011-02-23 00:00:00 MA_JCSC               MA_JCSC
# 2011-03-23 00:00:00 MA_JCSC               MA_JCSC

# %%
Account.cash_table
# Out:
#                                       cash             datetime       date  \
# datetime            account_cookie
# 2007-12-13 00:00:00 MA_JCSC         376144  2007-12-13 00:00:00 2007-12-13
# 2008-07-07 00:00:00 MA_JCSC         500339  2008-07-07 00:00:00 2008-07-07
# 2008-10-06 00:00:00 MA_JCSC         385810  2008-10-06 00:00:00 2008-10-06
# 2008-10-14 00:00:00 MA_JCSC         496921  2008-10-14 00:00:00 2008-10-14
# 2008-11-18 00:00:00 MA_JCSC         379242  2008-11-18 00:00:00 2008-11-18
# 2009-01-05 00:00:00 MA_JCSC         485359  2009-01-05 00:00:00 2009-01-05
# 2009-01-15 00:00:00 MA_JCSC         406714  2009-01-15 00:00:00 2009-01-15
# 2009-03-04 00:00:00 MA_JCSC         478524  2009-03-04 00:00:00 2009-03-04
# 2009-03-19 00:00:00 MA_JCSC         406506  2009-03-19 00:00:00 2009-03-19
# 2009-08-11 00:00:00 MA_JCSC         480913  2009-08-11 00:00:00 2009-08-11
# 2009-09-17 00:00:00 MA_JCSC         398642  2009-09-17 00:00:00 2009-09-17
# 2009-09-29 00:00:00 MA_JCSC         330125  2009-09-29 00:00:00 2009-09-29
# 2009-10-27 00:00:00 MA_JCSC         467753  2009-10-27 00:00:00 2009-10-27
# 2009-12-17 00:00:00 MA_JCSC         400536  2009-12-17 00:00:00 2009-12-17
# 2010-01-14 00:00:00 MA_JCSC         468676  2010-01-14 00:00:00 2010-01-14
# 2010-01-28 00:00:00 MA_JCSC         402660  2010-01-28 00:00:00 2010-01-28
# 2010-03-02 00:00:00 MA_JCSC         466804  2010-03-02 00:00:00 2010-03-02
# 2010-03-17 00:00:00 MA_JCSC         432796  2010-03-17 00:00:00 2010-03-17
# 2010-03-31 00:00:00 MA_JCSC         464955  2010-03-31 00:00:00 2010-03-31
# 2010-04-29 00:00:00 MA_JCSC         435173  2010-04-29 00:00:00 2010-04-29
# 2010-06-09 00:00:00 MA_JCSC         464836  2010-06-09 00:00:00 2010-06-09
# 2010-07-02 00:00:00 MA_JCSC         443156  2010-07-02 00:00:00 2010-07-02
# 2010-07-23 00:00:00 MA_JCSC         462531  2010-07-23 00:00:00 2010-07-23
# 2010-09-30 00:00:00 MA_JCSC         441451  2010-09-30 00:00:00 2010-09-30
# 2010-10-15 00:00:00 MA_JCSC         466669  2010-10-15 00:00:00 2010-10-15
# 2010-11-23 00:00:00 MA_JCSC         439988  2010-11-23 00:00:00 2010-11-23
# 2010-12-15 00:00:00 MA_JCSC         473795  2010-12-15 00:00:00 2010-12-15
# 2010-12-29 00:00:00 MA_JCSC         438536  2010-12-29 00:00:00 2010-12-29
# 2011-02-18 00:00:00 MA_JCSC         469847  2011-02-18 00:00:00 2011-02-18
# 2011-03-24 00:00:00 MA_JCSC         436039  2011-03-24 00:00:00 2011-03-24
# ...                                    ...                  ...        ...
# 2013-12-10 00:00:00 MA_JCSC           None  2013-12-10 00:00:00 2013-12-10
# 2013-12-12 00:00:00 MA_JCSC           None  2013-12-12 00:00:00 2013-12-12
# 2013-12-19 00:00:00 MA_JCSC           None  2013-12-19 00:00:00 2013-12-19
# 2014-01-09 00:00:00 MA_JCSC           None  2014-01-09 00:00:00 2014-01-09
# 2014-01-17 00:00:00 MA_JCSC           None  2014-01-17 00:00:00 2014-01-17
# 2014-01-27 00:00:00 MA_JCSC           None  2014-01-27 00:00:00 2014-01-27
# 2014-02-10 00:00:00 MA_JCSC           None  2014-02-10 00:00:00 2014-02-10
# 2014-02-24 00:00:00 MA_JCSC           None  2014-02-24 00:00:00 2014-02-24
# 2014-03-06 00:00:00 MA_JCSC           None  2014-03-06 00:00:00 2014-03-06
# 2014-03-10 00:00:00 MA_JCSC           None  2014-03-10 00:00:00 2014-03-10
# 2014-03-18 00:00:00 MA_JCSC           None  2014-03-18 00:00:00 2014-03-18
# 2014-04-02 00:00:00 MA_JCSC           None  2014-04-02 00:00:00 2014-04-02
# 2014-04-03 00:00:00 MA_JCSC           None  2014-04-03 00:00:00 2014-04-03
# 2014-04-04 00:00:00 MA_JCSC           None  2014-04-04 00:00:00 2014-04-04
# 2014-04-08 00:00:00 MA_JCSC           None  2014-04-08 00:00:00 2014-04-08
# 2014-04-17 00:00:00 MA_JCSC           None  2014-04-17 00:00:00 2014-04-17
# 2014-05-08 00:00:00 MA_JCSC           None  2014-05-08 00:00:00 2014-05-08
# 2014-08-05 00:00:00 MA_JCSC           None  2014-08-05 00:00:00 2014-08-05
# 2014-08-12 00:00:00 MA_JCSC           None  2014-08-12 00:00:00 2014-08-12
# 2014-08-15 00:00:00 MA_JCSC           None  2014-08-15 00:00:00 2014-08-15
# 2014-09-03 00:00:00 MA_JCSC           None  2014-09-03 00:00:00 2014-09-03
# 2014-09-16 00:00:00 MA_JCSC           None  2014-09-16 00:00:00 2014-09-16
# 2014-09-25 00:00:00 MA_JCSC           None  2014-09-25 00:00:00 2014-09-25
# 2014-10-16 00:00:00 MA_JCSC           None  2014-10-16 00:00:00 2014-10-16
# 2014-10-31 00:00:00 MA_JCSC           None  2014-10-31 00:00:00 2014-10-31
# 2014-11-11 00:00:00 MA_JCSC           None  2014-11-11 00:00:00 2014-11-11
# 2014-11-19 00:00:00 MA_JCSC           None  2014-11-19 00:00:00 2014-11-19
# 2014-12-03 00:00:00 MA_JCSC           None  2014-12-03 00:00:00 2014-12-03
# 2014-12-17 00:00:00 MA_JCSC           None  2014-12-17 00:00:00 2014-12-17
# 2014-12-22 00:00:00 MA_JCSC           None  2014-12-22 00:00:00 2014-12-22
#
#                                    account_cookie
# datetime            account_cookie
# 2007-12-13 00:00:00 MA_JCSC               MA_JCSC
# 2008-07-07 00:00:00 MA_JCSC               MA_JCSC
# 2008-10-06 00:00:00 MA_JCSC               MA_JCSC
# 2008-10-14 00:00:00 MA_JCSC               MA_JCSC
# 2008-11-18 00:00:00 MA_JCSC               MA_JCSC
# 2009-01-05 00:00:00 MA_JCSC               MA_JCSC
# 2009-01-15 00:00:00 MA_JCSC               MA_JCSC
# 2009-03-04 00:00:00 MA_JCSC               MA_JCSC
# 2009-03-19 00:00:00 MA_JCSC               MA_JCSC
# 2009-08-11 00:00:00 MA_JCSC               MA_JCSC
# 2009-09-17 00:00:00 MA_JCSC               MA_JCSC
# 2009-09-29 00:00:00 MA_JCSC               MA_JCSC
# 2009-10-27 00:00:00 MA_JCSC               MA_JCSC
# 2009-12-17 00:00:00 MA_JCSC               MA_JCSC
# 2010-01-14 00:00:00 MA_JCSC               MA_JCSC
# 2010-01-28 00:00:00 MA_JCSC               MA_JCSC
# 2010-03-02 00:00:00 MA_JCSC               MA_JCSC
# 2010-03-17 00:00:00 MA_JCSC               MA_JCSC
# 2010-03-31 00:00:00 MA_JCSC               MA_JCSC
# 2010-04-29 00:00:00 MA_JCSC               MA_JCSC
# 2010-06-09 00:00:00 MA_JCSC               MA_JCSC
# 2010-07-02 00:00:00 MA_JCSC               MA_JCSC
# 2010-07-23 00:00:00 MA_JCSC               MA_JCSC
# 2010-09-30 00:00:00 MA_JCSC               MA_JCSC
# 2010-10-15 00:00:00 MA_JCSC               MA_JCSC
# 2010-11-23 00:00:00 MA_JCSC               MA_JCSC
# 2010-12-15 00:00:00 MA_JCSC               MA_JCSC
# 2010-12-29 00:00:00 MA_JCSC               MA_JCSC
# 2011-02-18 00:00:00 MA_JCSC               MA_JCSC
# 2011-03-24 00:00:00 MA_JCSC               MA_JCSC
# ...                                           ...
# 2013-12-10 00:00:00 MA_JCSC               MA_JCSC
# 2013-12-12 00:00:00 MA_JCSC               MA_JCSC
# 2013-12-19 00:00:00 MA_JCSC               MA_JCSC
# 2014-01-09 00:00:00 MA_JCSC               MA_JCSC
# 2014-01-17 00:00:00 MA_JCSC               MA_JCSC
# 2014-01-27 00:00:00 MA_JCSC               MA_JCSC
# 2014-02-10 00:00:00 MA_JCSC               MA_JCSC
# 2014-02-24 00:00:00 MA_JCSC               MA_JCSC
# 2014-03-06 00:00:00 MA_JCSC               MA_JCSC
# 2014-03-10 00:00:00 MA_JCSC               MA_JCSC
# 2014-03-18 00:00:00 MA_JCSC               MA_JCSC
# 2014-04-02 00:00:00 MA_JCSC               MA_JCSC
# 2014-04-03 00:00:00 MA_JCSC               MA_JCSC
# 2014-04-04 00:00:00 MA_JCSC               MA_JCSC
# 2014-04-08 00:00:00 MA_JCSC               MA_JCSC
# 2014-04-17 00:00:00 MA_JCSC               MA_JCSC
# 2014-05-08 00:00:00 MA_JCSC               MA_JCSC
# 2014-08-05 00:00:00 MA_JCSC               MA_JCSC
# 2014-08-12 00:00:00 MA_JCSC               MA_JCSC
# 2014-08-15 00:00:00 MA_JCSC               MA_JCSC
# 2014-09-03 00:00:00 MA_JCSC               MA_JCSC
# 2014-09-16 00:00:00 MA_JCSC               MA_JCSC
# 2014-09-25 00:00:00 MA_JCSC               MA_JCSC
# 2014-10-16 00:00:00 MA_JCSC               MA_JCSC
# 2014-10-31 00:00:00 MA_JCSC               MA_JCSC
# 2014-11-11 00:00:00 MA_JCSC               MA_JCSC
# 2014-11-19 00:00:00 MA_JCSC               MA_JCSC
# 2014-12-03 00:00:00 MA_JCSC               MA_JCSC
# 2014-12-17 00:00:00 MA_JCSC               MA_JCSC
# 2014-12-22 00:00:00 MA_JCSC               MA_JCSC
#
# [865 rows x 4 columns]

# %%
Account.daily_cash
# Out:
#                                 date          cash             datetime  \
# date       account_cookie
# 2007-08-30 MA_JCSC        2007-08-30           NaN  2007-08-30 00:00:00
# 2007-08-31 MA_JCSC        2007-08-31           NaN  2007-08-30 00:00:00
# 2007-09-03 MA_JCSC        2007-09-03           NaN  2007-09-03 00:00:00
# 2007-09-04 MA_JCSC        2007-09-04           NaN  2007-09-03 00:00:00
# 2007-09-05 MA_JCSC        2007-09-05           NaN  2007-09-03 00:00:00
# 2007-09-06 MA_JCSC        2007-09-06           NaN  2007-09-03 00:00:00
# 2007-09-07 MA_JCSC        2007-09-07           NaN  2007-09-03 00:00:00
# 2007-09-10 MA_JCSC        2007-09-10           NaN  2007-09-03 00:00:00
# 2007-09-11 MA_JCSC        2007-09-11           NaN  2007-09-03 00:00:00
# 2007-09-12 MA_JCSC        2007-09-12           NaN  2007-09-03 00:00:00
# 2007-09-13 MA_JCSC        2007-09-13           NaN  2007-09-03 00:00:00
# 2007-09-14 MA_JCSC        2007-09-14           NaN  2007-09-03 00:00:00
# 2007-09-17 MA_JCSC        2007-09-17           NaN  2007-09-03 00:00:00
# 2007-09-18 MA_JCSC        2007-09-18           NaN  2007-09-03 00:00:00
# 2007-09-19 MA_JCSC        2007-09-19           NaN  2007-09-19 00:00:00
# 2007-09-20 MA_JCSC        2007-09-20           NaN  2007-09-19 00:00:00
# 2007-09-21 MA_JCSC        2007-09-21           NaN  2007-09-19 00:00:00
# 2007-09-24 MA_JCSC        2007-09-24           NaN  2007-09-19 00:00:00
# 2007-09-25 MA_JCSC        2007-09-25           NaN  2007-09-25 00:00:00
# 2007-09-26 MA_JCSC        2007-09-26           NaN  2007-09-25 00:00:00
# 2007-09-27 MA_JCSC        2007-09-27           NaN  2007-09-25 00:00:00
# 2007-09-28 MA_JCSC        2007-09-28           NaN  2007-09-25 00:00:00
# 2007-10-08 MA_JCSC        2007-10-08           NaN  2007-09-25 00:00:00
# 2007-10-09 MA_JCSC        2007-10-09           NaN  2007-09-25 00:00:00
# 2007-10-10 MA_JCSC        2007-10-10           NaN  2007-10-10 00:00:00
# 2007-10-11 MA_JCSC        2007-10-11           NaN  2007-10-11 00:00:00
# 2007-10-12 MA_JCSC        2007-10-12           NaN  2007-10-12 00:00:00
# 2007-10-15 MA_JCSC        2007-10-15           NaN  2007-10-12 00:00:00
# 2007-10-16 MA_JCSC        2007-10-16  480115.70000  2007-10-16 00:00:00
# 2007-10-17 MA_JCSC        2007-10-17  480115.70000  2007-10-17 00:00:00
# ...                              ...           ...                  ...
# 2014-11-20 MA_JCSC        2014-11-20  480758.11250  2014-11-20 00:00:00
# 2014-11-21 MA_JCSC        2014-11-21  480758.11250  2014-11-21 00:00:00
# 2014-11-24 MA_JCSC        2014-11-24  480758.11250  2014-11-24 00:00:00
# 2014-11-25 MA_JCSC        2014-11-25  480758.11250  2014-11-25 00:00:00
# 2014-11-26 MA_JCSC        2014-11-26  480758.11250  2014-11-26 00:00:00
# 2014-11-27 MA_JCSC        2014-11-27  480758.11250  2014-11-27 00:00:00
# 2014-11-28 MA_JCSC        2014-11-28  480758.11250  2014-11-28 00:00:00
# 2014-12-01 MA_JCSC        2014-12-01  451975.91875  2014-12-01 00:00:00
# 2014-12-02 MA_JCSC        2014-12-02  451975.91875  2014-12-02 00:00:00
# 2014-12-03 MA_JCSC        2014-12-03  451975.91875  2014-12-03 00:00:00
# 2014-12-04 MA_JCSC        2014-12-04  451975.91875  2014-12-04 00:00:00
# 2014-12-05 MA_JCSC        2014-12-05  451975.91875  2014-12-04 00:00:00
# 2014-12-08 MA_JCSC        2014-12-08  451975.91875  2014-12-08 00:00:00
# 2014-12-09 MA_JCSC        2014-12-09  451975.91875  2014-12-09 00:00:00
# 2014-12-10 MA_JCSC        2014-12-10  451975.91875  2014-12-10 00:00:00
# 2014-12-11 MA_JCSC        2014-12-11  451975.91875  2014-12-11 00:00:00
# 2014-12-12 MA_JCSC        2014-12-12  451975.91875  2014-12-12 00:00:00
# 2014-12-15 MA_JCSC        2014-12-15  451975.91875  2014-12-12 00:00:00
# 2014-12-16 MA_JCSC        2014-12-16  451975.91875  2014-12-12 00:00:00
# 2014-12-17 MA_JCSC        2014-12-17  451975.91875  2014-12-17 00:00:00
# 2014-12-18 MA_JCSC        2014-12-18  451975.91875  2014-12-17 00:00:00
# 2014-12-19 MA_JCSC        2014-12-19  451975.91875  2014-12-17 00:00:00
# 2014-12-22 MA_JCSC        2014-12-22  451975.91875  2014-12-22 00:00:00
# 2014-12-23 MA_JCSC        2014-12-23  451975.91875  2014-12-22 00:00:00
# 2014-12-24 MA_JCSC        2014-12-24  451975.91875  2014-12-22 00:00:00
# 2014-12-25 MA_JCSC        2014-12-25  451975.91875  2014-12-22 00:00:00
# 2014-12-26 MA_JCSC        2014-12-26  451975.91875  2014-12-22 00:00:00
# 2014-12-29 MA_JCSC        2014-12-29  451975.91875  2014-12-22 00:00:00
# 2014-12-30 MA_JCSC        2014-12-30  451975.91875  2014-12-30 00:00:00
# 2014-12-31 MA_JCSC        2014-12-31  451975.91875  2014-12-31 00:00:00
#
#                           account_cookie
# date       account_cookie
# 2007-08-30 MA_JCSC               MA_JCSC
# 2007-08-31 MA_JCSC               MA_JCSC
# 2007-09-03 MA_JCSC               MA_JCSC
# 2007-09-04 MA_JCSC               MA_JCSC
# 2007-09-05 MA_JCSC               MA_JCSC
# 2007-09-06 MA_JCSC               MA_JCSC
# 2007-09-07 MA_JCSC               MA_JCSC
# 2007-09-10 MA_JCSC               MA_JCSC
# 2007-09-11 MA_JCSC               MA_JCSC
# 2007-09-12 MA_JCSC               MA_JCSC
# 2007-09-13 MA_JCSC               MA_JCSC
# 2007-09-14 MA_JCSC               MA_JCSC
# 2007-09-17 MA_JCSC               MA_JCSC
# 2007-09-18 MA_JCSC               MA_JCSC
# 2007-09-19 MA_JCSC               MA_JCSC
# 2007-09-20 MA_JCSC               MA_JCSC
# 2007-09-21 MA_JCSC               MA_JCSC
# 2007-09-24 MA_JCSC               MA_JCSC
# 2007-09-25 MA_JCSC               MA_JCSC
# 2007-09-26 MA_JCSC               MA_JCSC
# 2007-09-27 MA_JCSC               MA_JCSC
# 2007-09-28 MA_JCSC               MA_JCSC
# 2007-10-08 MA_JCSC               MA_JCSC
# 2007-10-09 MA_JCSC               MA_JCSC
# 2007-10-10 MA_JCSC               MA_JCSC
# 2007-10-11 MA_JCSC               MA_JCSC
# 2007-10-12 MA_JCSC               MA_JCSC
# 2007-10-15 MA_JCSC               MA_JCSC
# 2007-10-16 MA_JCSC               MA_JCSC
# 2007-10-17 MA_JCSC               MA_JCSC
# ...                                  ...
# 2014-11-20 MA_JCSC               MA_JCSC
# 2014-11-21 MA_JCSC               MA_JCSC
# 2014-11-24 MA_JCSC               MA_JCSC
# 2014-11-25 MA_JCSC               MA_JCSC
# 2014-11-26 MA_JCSC               MA_JCSC
# 2014-11-27 MA_JCSC               MA_JCSC
# 2014-11-28 MA_JCSC               MA_JCSC
# 2014-12-01 MA_JCSC               MA_JCSC
# 2014-12-02 MA_JCSC               MA_JCSC
# 2014-12-03 MA_JCSC               MA_JCSC
# 2014-12-04 MA_JCSC               MA_JCSC
# 2014-12-05 MA_JCSC               MA_JCSC
# 2014-12-08 MA_JCSC               MA_JCSC
# 2014-12-09 MA_JCSC               MA_JCSC
# 2014-12-10 MA_JCSC               MA_JCSC
# 2014-12-11 MA_JCSC               MA_JCSC
# 2014-12-12 MA_JCSC               MA_JCSC
# 2014-12-15 MA_JCSC               MA_JCSC
# 2014-12-16 MA_JCSC               MA_JCSC
# 2014-12-17 MA_JCSC               MA_JCSC
# 2014-12-18 MA_JCSC               MA_JCSC
# 2014-12-19 MA_JCSC               MA_JCSC
# 2014-12-22 MA_JCSC               MA_JCSC
# 2014-12-23 MA_JCSC               MA_JCSC
# 2014-12-24 MA_JCSC               MA_JCSC
# 2014-12-25 MA_JCSC               MA_JCSC
# 2014-12-26 MA_JCSC               MA_JCSC
# 2014-12-29 MA_JCSC               MA_JCSC
# 2014-12-30 MA_JCSC               MA_JCSC
# 2014-12-31 MA_JCSC               MA_JCSC
#
# [1784 rows x 4 columns]

# %%
print(N1, N2)
# Out:
# 5 8

# %%
Account.history_table.cash.iloc[-1]
# Out:
# 512783.55624999956

# %%
Account.cash_table.loc['2009-01-22 00:00:00',slice(None)]
# Out:
#                 cash             datetime       date account_cookie
# account_cookie
# MA_JCSC         None  2009-01-22 00:00:00 2009-01-22        MA_JCSC

# %%
N1 = 11
N2 = 23
# 会出现cash_table None, 而history_table不出现None的问题
# Out:
# 11

# %%
N2
# Out:
# 23

# %%
df_result = pd.DataFrame()
count = 0
for N1 in range(5, 21, 1):
    for N2 in range(10, 31, 1):
        if N1 >= N2:
            continue
        ind = data_hfq.add_func(MA_JCSC, N1, N2)
        Account.reset_assets(5e+5)

# %%
loop_count = 0
for N1 in range(5, 21, 1):
    for N2 in range(10, 31, 1):
        if N1 >= N2:
            continue
# Out:
# 270

# %% [markdown]
# ## 性能测试

# %%
Account.reset_assets(5e+5)
ind = data_hfq.add_func(MA_JCSC, 5, 10)

# %%
tic = time.process_time()
data_forbacktest = data.select_time('2007-08-10', '2014-12-31')

for items in data_forbacktest.panel_gen:
    for item in items.security_gen:
        daily_ind = ind.loc[item.index]
        if daily_ind.CROSS_JC.iloc[0] > 0:
            order = Account.send_order(
                code = item.code[0],
                time = item.date[0],
                amount = 2500,
                towards = QA.ORDER_DIRECTION.BUY,
                price = 0,
                order_model = QA.ORDER_MODEL.CLOSE,
                amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                )
            Broker.receive_order(QA.QA_Event(order=order, market_data=item))
            
            trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
            res = trade_mes.loc[order.account_cookie, order.realorder_id]
            order.trade(res.trade_id, res.trade_price, res.trade_amount,
                       res.trade_time)
            
        elif daily_ind.CROSS_SC.iloc[0] > 0:
            if Account.sell_available.get(item.code[0], 0)>0:
                order = Account.send_order(
                    code = item.code[0],
                    time = item.date[0],
                    amount = Account.sell_available.get(item.code[0], 0),
                    towards = QA.ORDER_DIRECTION.SELL,
                    price = 0,
                    order_model = QA.ORDER_MODEL.MARKET,
                    amount_model = QA.AMOUNT_MODEL.BY_AMOUNT
                    )
                Broker.receive_order(QA.QA_Event(order=order, market_data=item))
                
                trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                res = trade_mes.loc[order.account_cookie, order.realorder_id]
                order.trade(res.trade_id, res.trade_price, res.trade_amount,
                           res.trade_time)
    Account.settle()
toc = time.process_time()
print ("backtest Computation time : %.2fs" % (toc - tic))
# Out:
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# receive deal
# backtest Computation time : 36.97s

# %% [markdown]
# ## 完全copy

# %%
data_forbacktest = data.select_time('2007-08-10', '2014-12-31')
length = data_forbacktest.data.shape[0]

# %%
Account.reset_assets(5e+5)
ind = data_hfq.add_func(MA_JCSC, 5, 10)

# %%
data_forbacktest.close.iloc[45]
# Out:
# 41.450000000000003

# %%
data_forbacktest.date[0]
# Out:
# Timestamp('2007-08-10 00:00:00')

# %%
CLOSE = data_forbacktest.close
OPEN = data_forbacktest.open
costR = 0.003

# %%
dataNN = [] #? what is it
for N1 in range(5, 21, 2):
    for N2 in range(10, 31, 3):
        if N1 >= N2:
            continue
        Nmax = max(N1,N2) # ? when and where use it ?
        cash = np.zeros([length, 1])
        hold = np.zeros([length, 1])
        cash[0,0] = 1e+6
#         Assets = cash + hold
        Pos = 0
        recode = []
        
        buynum = 0
        sellnum = 0
        for i in range(length):
            if i <=Nmax:
#                 Assets[i,0] = Assets[0,0]
                cash[i,0] = cash[0,0]
                hold[i,0] = hold[0,0]
            else:
#                 Assets[i,0] = Assets[i-1,0]
                cash[i,0] = cash[i-1,0]
                hold[i,0] = hold[i-1,0] 
        
                isbuy = ((ind.iloc[i-1,2]>0) & (Pos == 0))
                issell = ((ind.iloc[i-1,3]<0) & (Pos>0) & (i-buysum>=3))
                
                if isbuy==0 & issell ==0:
                    if Pos != 0:
                        cash[i,0] = cash[i-1,0] + (CLOSE.iloc[i] - CLOSE.iloc[i-1]) * Pos
                if isbuy:
                    buysum = i
                    buytime = data_forbacktest.date[i]
                    buyprice = OPEN.iloc[i]
                    # 这里可以用波动值N来做优化
                    Pos = np.floor(cash[i,0] / buyprice / 100) * 100
                    costbuy = buyprice * Pos * costR
                    cash[i,0] = cash[i-1,0] - buyprice * Pos - costbuy
                    hold[i,0] = hold[i,0] + buyprice * Pos
                if issell:
                    selltime = data_forbacktest.date[i]
                    sellprice = OPEN.iloc[i]
                    costsell = sellprice * Pos * costR
                    cash[i, 0] = cash[i, 0] + sellprice * Pos - costsell
                    hold[i, 0] = 0

# %%
39 * 8 * 7 / 60 / 60
# Out:
# 0.6066666666666667

# %% [markdown]
# ## 仿matlab code实现

# %%
data.select_time('2007-08-10', '2014-12-31').data.shape[0]
# Out:
# 1626

# %%
# tic = time.process_time()
# # _count = 0
# # for i in data.index:
# #     print(i)
# print(data.index)
# toc = time.process_time()

# print('cost time : %.2fs' %(toc-tic))

# %%
data_forbacktest = data.select_time('2007-08-10', '2014-12-31')
length = data_forbacktest.data.shape[0]
for N1 in range(5, 21, 1):
    for N2 in range(10, 31, 1):
        if N1 >= N2:
            continue
        for i in range(length):
            if ind.iloc[0,2] > 0:

# %%
ind.iloc[0]
# Out:
# MA_SHORT    NaN
# MA_LONG     NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# Name: (2007-08-10 00:00:00, 002149), dtype: float64
